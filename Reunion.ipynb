# %%
import pickle 
import numpy as np
import pandas as pd

# %%
filepath = "diccionarios_secuecias/jerarquico/lista_final.pkl"
word_file = "diccionarios_secuecias/jerarquico/word_dict.csv" 
df_words = pd.read_csv(word_file)
pickle_off = open(filepath,"rb")
pickle_file = pickle.load(pickle_off)
pickle_file
# Out:
# [['001', [97, 44, 95]],
#  ['003', [2, 102, 61, 57, 78]],
#  ['004', [57, 95, 57, 88, 97]],
#  ['005', [2, 57, 75]],
#  ['006', [88, 90, 95, 57]],
#  ['008', [80, 81, 80, 31]],
#  ['009', [2, 26, 71, 85]],
#  ['010', [97, 86, 71, 63]],
#  ['011', [57, 57, 88, 88]],
#  ['013', [84, 67, 85, 59]],
#  ['014', [57, 97, 84, 75]],
#  ['015', [97, 57, 64, 85, 45]],
#  ['016', [57, 76, 95, 95]],
#  ['017', [97, 84, 95, 88]],
#  ['018', [49, 76, 57, 97, 65, 73]],
#  ['019', [2, 93, 101, 65, 80, 76, 84, 85]],
#  ['020', [2, 84, 78, 58, 97, 84, 37, 56]],
#  ['022', [2, 97, 57, 80, 51, 88]],
#  ['023', [97, 57, 57, 95, 82, 75]],
#  ['024', [2, 59, 85, 57, 33]],
#  ['026', [2, 57, 78, 91, 88]],
#  ['027', [88, 57, 57, 97, 75]],
#  ['029', [71, 57, 56, 91, 43]],
#  ['031', [84, 97, 58]],
#  ['032', [97, 57, 95]],
#  ['033', [97, 95, 64]],
#  ['034', [57, 58, 62, 85, 92, 85]],
#  ['035', [75, 60, 57, 60, 57, 85]],
#  ['037', [97, 95, 90, 95, 91, 85, 97]],
#  ['038', [2, 75, 45, 89, 58, 85]],
#  ['039', [80, 64, 15, 89, 80]],
#  ['041', [57, 33, 75, 85, 102]],
#  ['042', [84, 95, 83, 89]],
#  ['044', [2, 37, 92, 37]],
#  ['045', [57, 26, 73, 55, 95]],
#  ['046', [2, 57, 84, 89]],
#  ['047', [97, 64, 62, 82]],
#  ['048', [59, 88, 64, 88]],
#  ['049', [2, 88, 81, 92]],
#  ['051', [97, 90, 80, 74, 65]],
#  ['052', [26, 69, 100, 95, 85]],
#  ['053', [97, 101, 84, 90, 80]],
#  ['055', [97, 84, 69, 8]],
#  ['056', [95, 57, 88, 102]],
#  ['058', [37, 84, 84, 85]],
#  ['059', [84, 94, 84, 58, 95]],
#  ['060', [57, 38, 85, 95]],
#  ['061', [84, 84, 31, 85]],
#  ['062', [84, 37, 73, 90, 95]],
#  ['063', [97, 75, 57, 97]],
#  ['064', [97, 69, 76, 93, 95]],
#  ['065', [84, 57, 75, 65]],
#  ['066', [57, 64, 62, 85, 59]],
#  ['068', [97, 82, 49, 91]],
#  ['069', [97, 100, 80, 97]],
#  ['070', [57, 84, 93, 95]],
#  ['072', [97, 84, 31, 95]],
#  ['073', [88, 84, 85, 57]],
#  ['075', [57, 57, 73, 90, 95]],
#  ['076', [84, 25, 97]],
#  ['078', [97, 57, 80, 81, 57]],
#  ['079', [84, 64, 44, 86, 85]],
#  ['080', [2, 57, 75, 102, 80]],
#  ['081', [97, 88, 94]],
#  ['082', [57, 57, 89, 88, 97]],
#  ['083', [84, 57, 102, 56, 88]],
#  ['085', [57, 84, 58]],
#  ['086', [57, 31, 45]],
#  ['087', [2, 84, 90, 64, 25, 94, 76]],
#  ['088', [2, 84, 57, 57, 86, 88]],
#  ['091', [97, 80, 98, 64, 100, 24, 81]],
#  ['093', [49, 79, 57, 75, 95, 85]],
#  ['094', [97, 91, 48, 57, 78, 90]],
#  ['095', [17, 64, 88, 85]],
#  ['096', [2, 84, 80]],
#  ['097', [57, 57, 88, 60, 99]],
#  ['098', [57, 76, 98, 12, 58]],
#  ['099', [97, 57, 67, 88]],
#  ['101', [95, 90, 39, 95]],
#  ['102', [88, 57, 49, 60, 73, 95]],
#  ['103', [97, 57, 91, 88]],
#  ['104', [97, 95, 88]],
#  ['106', [75, 64, 57, 75, 101]],
#  ['109', [57, 80, 35]],
#  ['110', [2, 84, 57, 75, 75]],
#  ['111', [2, 84, 57, 57, 80]],
#  ['112', [49, 90, 95, 64, 98]],
#  ['114', [57, 67, 84, 57]],
#  ['115', [97, 100, 56]],
#  ['116', [102, 97, 81, 59, 98, 95]],
#  ['117', [49, 64, 39, 80, 95]],
#  ['118', [57, 84, 57, 88, 92]],
#  ['120', [57, 49, 85, 75]],
#  ['121', [88, 95, 91]],
#  ['123', [88, 97, 49, 58]],
#  ['124', [71, 101, 65, 90, 64]],
#  ['125', [57, 88, 99]],
#  ['126', [97, 86, 59, 88, 88, 57]],
#  ['127', [59, 38, 92, 76]],
#  ['128', [97, 57, 80, 85, 76, 91]],
#  ['129', [88, 88, 75, 97, 78]],
#  ['130', [97, 57, 49, 89]],
#  ['131', [71, 57, 57, 57]],
#  ['132', [57, 80, 98, 84, 85]],
#  ['133', [64, 57, 92, 80]],
#  ['134', [57, 66, 46, 60]],
#  ['135', [97, 88, 11, 58]],
#  ['136', [94, 97, 37, 95]],
#  ['137', [58, 84, 60, 75, 55]],
#  ['138', [57, 57, 97, 88, 57]],
#  ['140', [88, 86, 45, 97, 86]],
#  ['141', [57, 45, 66, 56]],
#  ['143', [57, 97, 64, 79, 47]],
#  ['144', [84, 88, 2, 102, 75]],
#  ['145', [57, 39, 84, 88, 100]],
#  ['146', [57, 57, 88, 90, 63]],
#  ['147', [57, 94, 57, 80, 97]],
#  ['148', [91, 57, 80, 85, 79]],
#  ['149', [85, 64, 27, 75, 99]],
#  ['150', [57, 84, 86, 98, 75, 57]],
#  ['151', [84, 86, 54, 85, 80, 80]],
#  ['152', [67, 64, 80, 95, 80, 45]],
#  ['153', [64, 85]],
#  ['154', [2, 31]],
#  ['155', [59, 57, 75, 88]],
#  ['156', [90, 80, 37]],
#  ['157', [57, 64, 76, 57, 88]],
#  ['159', [101, 100, 64]],
#  ['160', [97, 57, 94]],
#  ['161', [101, 64, 85, 17]],
#  ['162', [88, 61, 89]],
#  ['163', [97, 74]],
#  ['164', [83]],
#  ['165', [2, 77]],
#  ['166', [97, 39, 101, 61, 85]],
#  ['168', [89, 84]],
#  ['169', [88, 59, 57, 55, 91]],
#  ['170', [64, 93, 76]],
#  ['172', [95, 100, 88, 57]],
#  ['173', [57, 84, 80, 57]],
#  ['175', [57, 57, 49, 88, 17]],
#  ['176', [89, 86, 75, 95, 88]],
#  ['177', [25, 73, 94]],
#  ['178', [71, 80]],
#  ['179', [97, 97]],
#  ['180', [57, 93]],
#  ['182', [57, 90, 84, 99, 84]],
#  ['183', [57, 45, 97, 97, 75]],
#  ['185', [57, 64, 80, 85, 95]],
#  ['186', [97, 91, 57, 88, 85]],
#  ['187', [91, 42, 89, 53, 73, 88]],
#  ['188', [88, 57, 84, 101]],
#  ['190', [57, 71, 81, 43, 62]],
#  ['191', [95, 76, 62, 80]],
#  ['192', [57, 90, 80, 57]],
#  ['194', [2, 102, 67, 88]],
#  ['195', [2, 45, 43, 95, 58, 57, 76]],
#  ['196', [85, 57, 24]],
#  ['197', [56, 31, 66, 97]],
#  ['198', [25, 45, 80]],
#  ['200', [97, 90, 75, 88]]]

# %%
word = "john"
df_words[df_words["word"] == word]
# Out:
#    word  id  Frecuency
# 0  john   0        113

# %%
def wer(r, h):
    # initialisation
    import numpy
    d = numpy.zeros((len(r)+1)*(len(h)+1), dtype=numpy.uint8)
    d = d.reshape((len(r)+1, len(h)+1))
    for i in range(len(r)+1):
        for j in range(len(h)+1):
            if i == 0:
                d[0][j] = j
            elif j == 0:
                d[i][0] = i

    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                d[i][j] = d[i-1][j-1]
            else:
                substitution = d[i-1][j-1] + 1
                insertion    = d[i][j-1] + 1
                deletion     = d[i-1][j] + 1
                d[i][j] = min(substitution, insertion, deletion)
    
    result = float(d[len(r)][len(h)]) /len(r)
    
    #if(result > 1):
    #    result = 1
        
    return result

# %%
a = "This is it"
b = "Tasd iasd asd asd  asd "
wer(a.split(),b.split())
# Out:
# 1.6666666666666667
