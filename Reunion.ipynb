# %%
import pickle 
import numpy as np
import pandas as pd

# %%
filepath = "diccionarios_secuecias/jerarquico/lista_final.pkl"
training_file = "train.sentences.pronunciations.multi.translations.csv"
word_file = "diccionarios_secuecias/jerarquico/word_dict.csv" 
df_training = pd.read_csv(training_file, delimiter=";")
df_words = pd.read_csv(word_file)
pickle_off = open(filepath,"rb")
pickle_file = pickle.load(pickle_off)

# %%
word = "go"
res = df_words[df_words["word"] == word]
res.id
print(df_words)
# Out:
#               word   id  Frecuency
# 0             john    0        113
# 1               ix    1         52
# 2             mary    2         37
# 3             what    3         26
# 4              who    4         25
# 5              buy    5         22
# 6             book    6         18
# 7             give    7         18
# 8              can    8         17
# 9               go    9         17
# 10          future   10         17
# 11             car   11         16
# 12          arrive   12         15
# 13            love   13         14
# 14            like   14         12
# 15          should   15         12
# 16            poss   16         12
# 17           visit   17         11
# 18       yesterday   18         10
# 19           house   19         10
# 20             not   20         10
# 21   something-one   21         10
# 22             see   22          9
# 23          prefer   23          7
# 24           woman   24          7
# 25       vegetable   25          6
# 26            bill   26          6
# 27           ix-1p   27          5
# 28             eat   28          5
# 29            corn   29          5
# ..             ...  ...        ...
# 73            jana   73          2
# 74             toy   74          2
# 75             all   75          2
# 76           write   76          1
# 77        homework   77          1
# 78           party   78          1
# 79             hit   79          1
# 80            fred   80          1
# 81            past   81          1
# 82            live   82          1
# 83         chicago   83          1
# 84        tomorrow   84          1
# 85       next-week   85          1
# 86       last-week   86          1
# 87             ann   87          1
# 88            find   88          1
# 89      search-for   89          1
# 90             leg   90          1
# 91          friend   91          1
# 92           candy   92          1
# 93             old   93          1
# 94          borrow   94          1
# 95          potato   95          1
# 96            name   96          1
# 97           shoot   97          1
# 98          say-1p   98          1
# 99           group   99          1
# 100           many  100          1
# 101            get  101          1
# 102       putaside  102          1
#
# [103 rows x 3 columns]

# %%
def wer(r, h):
    # initialisation
    import numpy
    d = numpy.zeros((len(r)+1)*(len(h)+1), dtype=numpy.uint8)
    d = d.reshape((len(r)+1, len(h)+1))
    for i in range(len(r)+1):
        for j in range(len(h)+1):
            if i == 0:
                d[0][j] = j
            elif j == 0:
                d[i][0] = i

    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                d[i][j] = d[i-1][j-1]
            else:
                substitution = d[i-1][j-1] + 1
                insertion    = d[i][j-1] + 1
                deletion     = d[i-1][j] + 1
                d[i][j] = min(substitution, insertion, deletion)
    
    result = float(d[len(r)][len(h)]) /len(r)
    
    #if(result > 1):
    #    result = 1
        
    return result

# %%
WER = wer(a.split(),b.split())

# %%
df_training = df_training[["video","orth"]]

# %%
for i in range (len(df_training)):
    sentence  = df_training.orth.iloc[i]
    lista = sentence.split()
    lista = lista[1:len(lista)-1]
    df_training.at[i,"orth"] = lista
    print(lista)
# Out:
# ['JOHN', 'WRITE', 'HOMEWORK']
# ['IX-1P', 'SEE', 'JOHN', 'YESTERDAY', 'IX']
# ['JOHN', 'IX-1P', 'SEE', 'IX', 'YESTERDAY']
# ['LOVE', 'MARY', 'JOHN']
# ['LOVE', 'MARY', 'JOHN', 'IX']
# ['JOHN', 'CAN', 'GO', 'CAN']
# ['JOHN', 'CAN', 'GO1', 'CAN']
# ['JOHN', 'CAN', 'GO', 'CAN']
# ['JOHN', 'CAN', 'GO1', 'CAN']
# ['JOHN', 'CAN', 'GO1', 'CAN']
# ['JOHN', 'CAN', 'GO1', 'CAN']
# ['JOHN', 'FUTURE', 'GO2', 'PARTY', 'FUTURE']
# ['JOHN', 'FUTURE1', 'GO', 'IX']
# ['JOHN', 'FUTURE1', 'GO', 'IX']
# ['JOHN', 'IX', 'HIT', 'BLAME', 'FRED', 'IX']
# ['JOHN', 'FISH', 'WONT', 'EAT', 'BUT', 'CAN', 'EAT', 'CHICKEN']
# ['JOHN', 'FISH', 'WONT', 'EAT', 'BUT', 'CAN', 'EAT', 'CHICKEN']
# ['VEGETABLE', 'CHINA', 'IX', 'PEOPLE', 'PREFER', 'BROCCOLI']
# ['VEGETABLE', 'CHINA', 'IX', 'PEOPLE', 'PREFER', 'BROCCOLI']
# ['JOHN', 'LIKE', 'IX', 'IX', 'IX']
# ['JOHN', 'LIKE', 'IX', 'IX', 'IX']
# ['JOHN', 'LIKE', 'IX', 'IX', 'IX']
# ['JOHN', 'LIKE', 'IX', 'IX', 'IX']
# ['JOHN', 'LEAVE', 'IX']
# ['JOHN', 'LEAVE', 'IX']
# ['JOHN', 'LEAVE', 'IX']
# ['JOHN', 'SAY', 'MARY', 'IX-1P', 'BUY', 'HOUSE']
# ['MARY', 'VEGETABLE', 'KNOW', 'IX', 'LIKE', 'CORN']
# ['MARY', 'VEGETABLE', 'IX-1P', 'KNOW', 'IX', 'LIKE', 'CORN1']
# ['MARY', 'VEGETABLE', 'KNOW', 'IX', 'LIKE', 'CORN1']
# ['JOHN', 'IX', 'THINK', 'MARY', 'LOVE']
# ['JOHN', 'IX', 'THINK', 'MARY', 'LOVE']
# ['JOHN', 'CAN', 'BUY', 'HOUSE']
# ['JOHN', 'FUTURE', 'BUY', 'HOUSE']
# ['JOHN', 'FUTURE', 'NOT', 'BUY', 'HOUSE']
# ['JOHN', 'PAST', 'LIVE', 'CHICAGO']
# ['JOHN', 'BUY', 'CAR', 'FUTURE']
# ['JOHN', 'BUY', 'CAR', 'FUTURE']
# ['JOHN', 'BUY', 'CAR', 'SHOULD']
# ['JOHN', 'BUY', 'CAR', 'FUTURE', 'NOT']
# ['JOHN', 'SHOULD', 'NOT', 'BUY', 'HOUSE']
# ['JOHN', 'SHOULD', 'NOT', 'BUY', 'HOUSE']
# ['JOHN', 'SHOULD', 'BUY', 'HOUSE']
# ['JOHN', 'DECIDE', 'VISIT', 'MARY']
# ['JOHN', 'DECIDE', 'VISIT', 'MARY']
# ['JOHN', 'FUTURE', 'NOT', 'BUY', 'HOUSE']
# ['JOHN', 'PREFER', 'GO', 'MOVIE']
# ['JOHN', 'WANT', 'SELL', 'CAR']
# ['JOHN', 'WANT', 'SELL', 'CAR', 'FUTURE']
# ['FUTURE', 'JOHN', 'GO', 'FUTURE']
# ['JOHN', 'PREFER', 'GO', 'MOVIE', 'TOMORROW']
# ['NEXT-WEEK', 'JOHN', 'GO', 'NEW-YORK']
# ['JOHN', 'FUTURE', 'NOT', 'BUY', 'HOUSE']
# ['LAST-WEEK', 'JOHN', 'GO', 'NEW-YORK']
# ['JOHN', 'WILL', 'VISIT', 'MARY']
# ['JOHN', 'WILL', 'VISIT', 'MARY']
# ['JOHN', 'FINISH', 'VISIT', 'MARY']
# ['JOHN', 'NOT', 'VISIT', 'MARY']
# ['JOHN', 'FUTURE', 'FINISH', 'VISIT', 'MARY']
# ['ANN', 'BLAME', 'MARY']
# ['JOHN', 'FUTURE', 'FINISH', 'SEE', 'MARY']
# ['JOHN', 'SHOULD', 'FINISH', 'READ', 'BOOK']
# ['JOHN', 'FUTURE', 'FINISH', 'READ', 'BOOK']
# ['JOHN', 'LIKE', 'CHOCOLATE']
# ['JOHN', 'SHOULD', 'NOT', 'LIKE', 'CHOCOLATE']
# ['IX-1P', 'FIND', 'SOMETHING-ONE', 'POSS', 'BOOK']
# ['JOHN', 'BROTHER', 'ARRIVE']
# ['SOMETHING-ONE', 'ARRIVE', 'HERE']
# ['JOHN', 'GIVE', 'IX', 'MAN', 'IX', 'NEW', 'COAT']
# ['JOHN', 'GIVE', 'IX', 'MAN', 'NEW', 'COAT']
# ['JOHN', 'IX', 'GIVE', 'IX', 'WOMAN', 'IX', 'BOOK']
# ['JOHN', 'GIVE1', 'IX', 'SOMETHING-ONE', 'WOMAN', 'BOOK']
# ['JOHN', 'GIVE1', 'IX', 'SOMETHING-ONE', 'WOMAN', 'BOOK']
# ['IX', 'WOMAN', 'HAVE', 'BOOK']
# ['IX', 'HAVE', 'BOOK']
# ['FRANK', 'POSS', 'NEW', 'CAR', 'BREAK-DOWN']
# ['POSS', 'FRANK', 'NEW', 'CAR', 'BREAK-DOWN']
# ['FRANK', 'POSS', 'CAR', 'BREAK-DOWN']
# ['POSS', 'NEW', 'CAR', 'BREAK-DOWN']
# ['JOHN', 'SEARCH-FOR', 'WHO', 'POSS', 'BOOK', 'WHAT']
# ['JOHN', 'POSS', 'BROTHER', 'ARRIVE']
# ['JOHN', 'POSS', 'LEG']
# ['JOHN', 'POSS', 'FRIEND', 'POSS', 'CANDY']
# ['WOMAN', 'ARRIVE', 'HERE']
# ['WHAT', 'SOMETHING-ONE', 'WHAT', 'WOMAN', 'ARRIVE']
# ['WHAT', 'WOMAN', 'WHAT', 'ARRIVE', 'HERE']
# ['IX', 'CAR', 'BLUE', 'SUE', 'BUY1']
# ['SOMETHING-ONE', 'POSS', 'CAR', 'STOLEN']
# ['SOMETHING-ONE', 'CAR', 'STOLEN']
# ['JOHN', 'POSS', 'OLD', 'HOUSE', 'SELL', 'YESTERDAY']
# ['SUE', 'BUY1', 'IX', 'CAR', 'BLUE']
# ['SUE', 'BUY1', 'IX', 'CAR', 'BLUE']
# ['SUE', 'BUY1', 'CAR', 'BLUE']
# ['JOHN', 'READ', 'BOOK']
# ['SOMETHING-ONE', 'STUDENT', 'HAVE', 'VIDEOTAPE']
# ['SOMETHING-ONE', 'STUDENT', 'SOMETHING-ONE', 'BORROW', 'VIDEOTAPE']
# ['STUDENT', 'HAVE', 'VIDEOTAPE']
# ['JOHN', 'MOTHER', 'ARRIVE', 'WHO', 'MOTHER', 'ARRIVE']
# ['JOHN', 'SEE', 'WHO', 'WHAT']
# ['IX', 'JOHN', 'SEE', 'WHO', 'IX', 'WHO']
# ['WHAT', 'MARY', 'WONT', 'EAT', 'WHAT']
# ['JOHN', 'MARY', 'LOVE', 'IX']
# ['JOHN', 'IX', 'LIKE', 'MARY']
# ['WHO', 'VEGETABLE', 'PREFER', 'POTATO', 'WHAT']
# ['WHAT', 'JOHN', 'LOVE', 'WHAT']
# ['WHAT', 'JOHN', 'LOVE', 'WHAT']
# ['WHAT', 'JOHN', 'LOVE', 'WHAT']
# ['WHO', 'TELL', 'BILL', 'MARY']
# ['JOHN', 'BUY1', 'WHAT', 'YESTERDAY', 'BOOK']
# ['JOHN', 'BUY', 'WHAT', 'YESTERDAY', 'BOOK']
# ['JOHN', 'BUY', 'YESTERDAY', 'WHAT', 'BOOK']
# ['JOHN', 'BUY', 'WHAT', 'BOOK']
# ['TELL', 'BILL', 'YESTERDAY', 'WHO', 'MARY']
# ['TELL', 'BILL', 'YESTERDAY', 'WHO', 'MARY']
# ['WHO', 'TELL', 'BILL', 'WHAT', 'MARY']
# ['WHO', 'JOHN', 'VISIT', 'WHAT', 'MARY']
# ['TELL', 'BILL', 'YESTERDAY', 'WHO', 'MARY']
# ['JOHN', 'BUY1', 'YESTERDAY', 'WHAT', 'BOOK']
# ['WHO', 'JOHN', 'SEE', 'WHAT', 'MARY']
# ['JOHN', 'SEE', 'THROW', 'APPLE', 'WHO', 'MARY']
# ['JOHN', 'SEE', 'THROW', 'APPLE', 'WHO', 'MARY']
# ['JOHN', 'SEE', 'THROW', 'APPLE', 'WHO', 'MARY']
# ['ARRIVE', 'WHO']
# ['ARRIVE', 'WHO']
# ['JOHN', 'GO', 'SHOULD', 'SHOULD']
# ['JOHN', 'GO', 'SHOULD']
# ['JOHN', 'SHOULD', 'GO', 'SHOULD', 'SHOULD']
# ['LOVE', 'JOHN', 'WHO']
# ['LOVE', 'JOHN', 'WHO']
# ['WHO', 'JOHN', 'LOVE', 'WHO']
# ['WHAT', 'JOHN', 'LIKE']
# ['WHO', 'ARRIVE']
# ['NAME']
# ['SHOOT', 'FRANK']
# ['JOHN', 'IX', 'SAY-1P', 'LOVE', 'MARY']
# ['JOHN', 'BLAME']
# ['MARY', 'BILL', 'SAY', 'JOHN', 'LOVE']
# ['JOHN', 'MARY', 'BLAME']
# ['MARY', 'SELF', 'PREFER', 'CORN']
# ['MARY', 'SELF', 'PREFER', 'CORN']
# ['PEOPLE', 'GROUP', 'GIVE1', 'JANA', 'TOY']
# ['MANY', 'PEOPLE', 'GIVE1', 'JANA', 'TOY1']
# ['JOHN', 'LOVE', 'MARY']
# ['JOHN', 'ARRIVE']
# ['JOHN', 'ARRIVE']
# ['JOHN', 'ARRIVE']
# ['ALL', 'BOY', 'GIVE1', 'TEACHER', 'APPLE']
# ['ALL', 'BOY', 'GIVE1', 'TEACHER', 'APPLE']
# ['IX', 'GIRL', 'GIVE', 'JOHN', 'BOX']
# ['IX', 'GIRL', 'GIVE2', 'JOHN', 'BOX']
# ['TEACHER', 'GIVE', 'GIVE', 'GIVE', 'BOY', 'BOOK']
# ['TEACHER', 'GIVE3', 'BOY', 'BOOK']
# ['IX', 'GIRL', 'GIVE', 'JOHN', 'BOX']
# ['JOHN', 'GIVE', 'GIRL', 'BOX']
# ['JOHN', 'GIVE3', 'GIRL', 'BOX']
# ['JOHN', 'CAN', 'GET', 'CAN']
# ['JOHN', 'NOT', 'VISIT', 'MARY', 'VISIT', 'MOTHER', 'IX']
# ['IX', 'BOOK', 'PUTASIDE']
# ['JOHN', 'ARRIVE', 'NOT', 'WHAT']
# ['LIKE', 'CHOCOLATE', 'WHO']
# ['JOHN', 'VISIT', 'WHO', 'WHAT']

# %%
df_jeff = pd.DataFrame(columns=["video","orth"])
for i in range (len(pickle_file)):
    lista = []
    pickle_file_row = pickle_file[i]
    pickle_file_video = pickle_file_row [0]
    pickle_file_index_list = pickle_file_row [1]
    for j in range (len(pickle_file_index_list)):
        indice = pickle_file_index_list[j]
        word = df_words[df_words["id"] ==indice].word.iloc[0]
        print(str.upper(word))
        lista.append(str.upper(word))
    df_jeff.at[i,"video"] = pickle_file_video
    df_jeff.at[i,"orth"] = lista
# Out:
# SHOOT
# TEACHER
# POTATO
# MARY
# PUTASIDE
# SAY
# BUT
# PARTY
# BUT
# POTATO
# BUT
# FIND
# SHOOT
# MARY
# BUT
# ALL
# FIND
# LEG
# POTATO
# BUT
# FRED
# PAST
# FRED
# NEW
# MARY
# BILL
# STOLEN
# NEXT-WEEK
# SHOOT
# LAST-WEEK
# STOLEN
# DECIDE
# BUT
# BUT
# FIND
# FIND
# TOMORROW
# WILL
# NEXT-WEEK
# CHINA
# BUT
# SHOOT
# TOMORROW
# ALL
# SHOOT
# BUT
# MOVIE
# NEXT-WEEK
# WONT
# BUT
# WRITE
# POTATO
# POTATO
# SHOOT
# TOMORROW
# POTATO
# FIND
# READ
# WRITE
# BUT
# SHOOT
# WANT
# JANA
# MARY
# OLD
# GET
# WANT
# FRED
# WRITE
# TOMORROW
# NEXT-WEEK
# MARY
# TOMORROW
# PARTY
# CHICKEN
# SHOOT
# TOMORROW
# PEOPLE
# FISH
# MARY
# SHOOT
# BUT
# FRED
# HERE
# FIND
# SHOOT
# BUT
# BUT
# POTATO
# LIVE
# ALL
# MARY
# CHINA
# NEXT-WEEK
# BUT
# APPLE
# MARY
# BUT
# PARTY
# FRIEND
# FIND
# FIND
# BUT
# BUT
# SHOOT
# ALL
# STOLEN
# BUT
# FISH
# FRIEND
# BOY
# TOMORROW
# SHOOT
# CHICKEN
# SHOOT
# BUT
# POTATO
# SHOOT
# POTATO
# MOVIE
# BUT
# CHICKEN
# THINK
# NEXT-WEEK
# CANDY
# NEXT-WEEK
# ALL
# BROCCOLI
# BUT
# BROCCOLI
# BUT
# NEXT-WEEK
# SHOOT
# POTATO
# LEG
# POTATO
# FRIEND
# NEXT-WEEK
# SHOOT
# MARY
# ALL
# WONT
# SEARCH-FOR
# CHICKEN
# NEXT-WEEK
# FRED
# MOVIE
# SHOULD
# SEARCH-FOR
# FRED
# BUT
# APPLE
# ALL
# NEXT-WEEK
# PUTASIDE
# TOMORROW
# POTATO
# CHICAGO
# SEARCH-FOR
# MARY
# PEOPLE
# CANDY
# PEOPLE
# BUT
# BILL
# JANA
# THROW
# POTATO
# MARY
# BUT
# TOMORROW
# SEARCH-FOR
# SHOOT
# MOVIE
# THINK
# LIVE
# CHINA
# FIND
# MOVIE
# FIND
# MARY
# FIND
# PAST
# CANDY
# SHOOT
# LEG
# FRED
# TOY
# WANT
# BILL
# MAN
# MANY
# POTATO
# NEXT-WEEK
# SHOOT
# GET
# TOMORROW
# LEG
# FRED
# SHOOT
# TOMORROW
# MAN
# CAN
# POTATO
# BUT
# FIND
# PUTASIDE
# PEOPLE
# TOMORROW
# TOMORROW
# NEXT-WEEK
# TOMORROW
# BORROW
# TOMORROW
# CHICKEN
# POTATO
# BUT
# HAVE
# NEXT-WEEK
# POTATO
# TOMORROW
# TOMORROW
# NEW
# NEXT-WEEK
# TOMORROW
# PEOPLE
# JANA
# LEG
# POTATO
# SHOOT
# ALL
# BUT
# SHOOT
# SHOOT
# MAN
# WRITE
# OLD
# POTATO
# TOMORROW
# BUT
# ALL
# WANT
# BUT
# MOVIE
# THINK
# NEXT-WEEK
# CHINA
# SHOOT
# LIVE
# READ
# FRIEND
# SHOOT
# MANY
# FRED
# SHOOT
# BUT
# TOMORROW
# OLD
# POTATO
# SHOOT
# TOMORROW
# NEW
# POTATO
# FIND
# TOMORROW
# NEXT-WEEK
# BUT
# BUT
# BUT
# JANA
# LEG
# POTATO
# TOMORROW
# VEGETABLE
# SHOOT
# SHOOT
# BUT
# FRED
# PAST
# BUT
# TOMORROW
# MOVIE
# TEACHER
# LAST-WEEK
# NEXT-WEEK
# MARY
# BUT
# ALL
# PUTASIDE
# FRED
# SHOOT
# FIND
# BORROW
# BUT
# BUT
# SEARCH-FOR
# FIND
# SHOOT
# TOMORROW
# BUT
# PUTASIDE
# FISH
# FIND
# BUT
# TOMORROW
# CHICKEN
# BUT
# NEW
# WONT
# MARY
# TOMORROW
# LEG
# MOVIE
# VEGETABLE
# BORROW
# WRITE
# MARY
# TOMORROW
# BUT
# BUT
# LAST-WEEK
# FIND
# SHOOT
# FRED
# SAY-1P
# MOVIE
# MANY
# WOMAN
# PAST
# READ
# HIT
# BUT
# ALL
# POTATO
# NEXT-WEEK
# SHOOT
# FRIEND
# SELL
# BUT
# PARTY
# LEG
# VISIT
# MOVIE
# FIND
# NEXT-WEEK
# MARY
# TOMORROW
# FRED
# BUT
# BUT
# FIND
# BROCCOLI
# GROUP
# BUT
# WRITE
# SAY-1P
# ARRIVE
# CHICKEN
# SHOOT
# BUT
# WILL
# FIND
# POTATO
# LEG
# FRANK
# POTATO
# FIND
# BUT
# READ
# BROCCOLI
# JANA
# POTATO
# SHOOT
# BUT
# FRIEND
# FIND
# SHOOT
# POTATO
# FIND
# ALL
# MOVIE
# BUT
# ALL
# GET
# BUT
# FRED
# BOX
# MARY
# TOMORROW
# BUT
# ALL
# ALL
# MARY
# TOMORROW
# BUT
# BUT
# FRED
# READ
# LEG
# POTATO
# MOVIE
# SAY-1P
# BUT
# WILL
# TOMORROW
# BUT
# SHOOT
# MANY
# FISH
# PUTASIDE
# SHOOT
# PAST
# CHINA
# SAY-1P
# POTATO
# READ
# MOVIE
# FRANK
# FRED
# POTATO
# BUT
# TOMORROW
# BUT
# FIND
# CANDY
# BUT
# READ
# NEXT-WEEK
# ALL
# FIND
# POTATO
# FRIEND
# FIND
# SHOOT
# READ
# CHICKEN
# STOLEN
# GET
# WANT
# LEG
# MOVIE
# BUT
# FIND
# GROUP
# SHOOT
# LAST-WEEK
# CHINA
# FIND
# FIND
# BUT
# CHINA
# HAVE
# CANDY
# WRITE
# SHOOT
# BUT
# FRED
# NEXT-WEEK
# WRITE
# FRIEND
# FIND
# FIND
# ALL
# SHOOT
# PARTY
# SHOOT
# BUT
# READ
# SEARCH-FOR
# STOLEN
# BUT
# BUT
# BUT
# BUT
# FRED
# SAY-1P
# TOMORROW
# NEXT-WEEK
# MOVIE
# BUT
# CANDY
# FRED
# BUT
# NEW-YORK
# LEAVE
# BROCCOLI
# SHOOT
# FIND
# CAR
# CHICKEN
# BORROW
# SHOOT
# PEOPLE
# POTATO
# CHICKEN
# TOMORROW
# BROCCOLI
# ALL
# THROW
# BUT
# BUT
# SHOOT
# FIND
# BUT
# FIND
# LAST-WEEK
# WONT
# SHOOT
# LAST-WEEK
# BUT
# WONT
# NEW-YORK
# FISH
# BUT
# SHOOT
# MOVIE
# HIT
# KNOW
# TOMORROW
# FIND
# MARY
# PUTASIDE
# ALL
# BUT
# FRANK
# TOMORROW
# FIND
# MANY
# BUT
# BUT
# FIND
# LEG
# DECIDE
# BUT
# BORROW
# BUT
# FRED
# SHOOT
# FRIEND
# BUT
# FRED
# NEXT-WEEK
# HIT
# NEXT-WEEK
# MOVIE
# IX-1P
# ALL
# GROUP
# BUT
# TOMORROW
# LAST-WEEK
# SAY-1P
# ALL
# BUT
# TOMORROW
# LAST-WEEK
# MOTHER
# NEXT-WEEK
# FRED
# FRED
# WILL
# MOVIE
# FRED
# POTATO
# FRED
# WONT
# MOVIE
# NEXT-WEEK
# MARY
# NEW
# CHINA
# BUT
# ALL
# FIND
# LEG
# FRED
# PEOPLE
# BUT
# MOVIE
# WRITE
# BUT
# FIND
# GET
# MANY
# MOVIE
# SHOOT
# BUT
# BORROW
# GET
# MOVIE
# NEXT-WEEK
# VISIT
# FIND
# SAY
# SEARCH-FOR
# SHOOT
# TOY
# CHICAGO
# MARY
# HOMEWORK
# SHOOT
# FRANK
# GET
# SAY
# NEXT-WEEK
# SEARCH-FOR
# TOMORROW
# FIND
# CHINA
# BUT
# THROW
# FRIEND
# MOVIE
# OLD
# WRITE
# POTATO
# MANY
# FIND
# BUT
# BUT
# TOMORROW
# FRED
# BUT
# BUT
# BUT
# READ
# FIND
# VISIT
# SEARCH-FOR
# LAST-WEEK
# ALL
# POTATO
# FIND
# VEGETABLE
# JANA
# BORROW
# STOLEN
# FRED
# SHOOT
# SHOOT
# BUT
# OLD
# BUT
# LEG
# TOMORROW
# GROUP
# TOMORROW
# BUT
# WONT
# SHOOT
# SHOOT
# ALL
# BUT
# MOVIE
# FRED
# NEXT-WEEK
# POTATO
# SHOOT
# FRIEND
# BUT
# FIND
# NEXT-WEEK
# FRIEND
# SUE
# SEARCH-FOR
# VIDEOTAPE
# JANA
# FIND
# FIND
# BUT
# TOMORROW
# GET
# BUT
# STOLEN
# PAST
# BOY
# THINK
# POTATO
# WRITE
# THINK
# FRED
# BUT
# LEG
# FRED
# BUT
# MARY
# PUTASIDE
# WILL
# FIND
# MARY
# WONT
# BOY
# POTATO
# CHICKEN
# BUT
# WRITE
# NEXT-WEEK
# BUT
# WOMAN
# FISH
# NEW
# NEW-YORK
# SHOOT
# VEGETABLE
# WONT
# FRED
# SHOOT
# LEG
# ALL
# FIND

# %%
df_jeff
# Out:
#     video                                               orth
# 0     001                           [SHOOT, TEACHER, POTATO]
# 1     003                  [MARY, PUTASIDE, SAY, BUT, PARTY]
# 2     004                    [BUT, POTATO, BUT, FIND, SHOOT]
# 3     005                                   [MARY, BUT, ALL]
# 4     006                           [FIND, LEG, POTATO, BUT]
# 5     008                            [FRED, PAST, FRED, NEW]
# 6     009                    [MARY, BILL, STOLEN, NEXT-WEEK]
# 7     010                 [SHOOT, LAST-WEEK, STOLEN, DECIDE]
# 8     011                             [BUT, BUT, FIND, FIND]
# 9     013                 [TOMORROW, WILL, NEXT-WEEK, CHINA]
# 10    014                        [BUT, SHOOT, TOMORROW, ALL]
# 11    015               [SHOOT, BUT, MOVIE, NEXT-WEEK, WONT]
# 12    016                       [BUT, WRITE, POTATO, POTATO]
# 13    017                    [SHOOT, TOMORROW, POTATO, FIND]
# 14    018              [READ, WRITE, BUT, SHOOT, WANT, JANA]
# 15    019  [MARY, OLD, GET, WANT, FRED, WRITE, TOMORROW, ...
# 16    020  [MARY, TOMORROW, PARTY, CHICKEN, SHOOT, TOMORR...
# 17    022               [MARY, SHOOT, BUT, FRED, HERE, FIND]
# 18    023               [SHOOT, BUT, BUT, POTATO, LIVE, ALL]
# 19    024               [MARY, CHINA, NEXT-WEEK, BUT, APPLE]
# 20    026                   [MARY, BUT, PARTY, FRIEND, FIND]
# 21    027                       [FIND, BUT, BUT, SHOOT, ALL]
# 22    029                   [STOLEN, BUT, FISH, FRIEND, BOY]
# 23    031                         [TOMORROW, SHOOT, CHICKEN]
# 24    032                               [SHOOT, BUT, POTATO]
# 25    033                             [SHOOT, POTATO, MOVIE]
# 26    034  [BUT, CHICKEN, THINK, NEXT-WEEK, CANDY, NEXT-W...
# 27    035     [ALL, BROCCOLI, BUT, BROCCOLI, BUT, NEXT-WEEK]
# 28    037  [SHOOT, POTATO, LEG, POTATO, FRIEND, NEXT-WEEK...
# 29    038  [MARY, ALL, WONT, SEARCH-FOR, CHICKEN, NEXT-WEEK]
# ..    ...                                                ...
# 131   163                                       [SHOOT, TOY]
# 132   164                                          [CHICAGO]
# 133   165                                   [MARY, HOMEWORK]
# 134   166                [SHOOT, FRANK, GET, SAY, NEXT-WEEK]
# 135   168                             [SEARCH-FOR, TOMORROW]
# 136   169                  [FIND, CHINA, BUT, THROW, FRIEND]
# 137   170                                [MOVIE, OLD, WRITE]
# 138   172                          [POTATO, MANY, FIND, BUT]
# 139   173                         [BUT, TOMORROW, FRED, BUT]
# 140   175                      [BUT, BUT, READ, FIND, VISIT]
# 141   176         [SEARCH-FOR, LAST-WEEK, ALL, POTATO, FIND]
# 142   177                          [VEGETABLE, JANA, BORROW]
# 143   178                                     [STOLEN, FRED]
# 144   179                                     [SHOOT, SHOOT]
# 145   180                                         [BUT, OLD]
# 146   182              [BUT, LEG, TOMORROW, GROUP, TOMORROW]
# 147   183                     [BUT, WONT, SHOOT, SHOOT, ALL]
# 148   185              [BUT, MOVIE, FRED, NEXT-WEEK, POTATO]
# 149   186              [SHOOT, FRIEND, BUT, FIND, NEXT-WEEK]
# 150   187   [FRIEND, SUE, SEARCH-FOR, VIDEOTAPE, JANA, FIND]
# 151   188                         [FIND, BUT, TOMORROW, GET]
# 152   190                    [BUT, STOLEN, PAST, BOY, THINK]
# 153   191                       [POTATO, WRITE, THINK, FRED]
# 154   192                              [BUT, LEG, FRED, BUT]
# 155   194                       [MARY, PUTASIDE, WILL, FIND]
# 156   195     [MARY, WONT, BOY, POTATO, CHICKEN, BUT, WRITE]
# 157   196                            [NEXT-WEEK, BUT, WOMAN]
# 158   197                       [FISH, NEW, NEW-YORK, SHOOT]
# 159   198                            [VEGETABLE, WONT, FRED]
# 160   200                            [SHOOT, LEG, ALL, FIND]
#
# [161 rows x 2 columns]

# %%
df_training
# Out:
#     video                                              orth
# 0    001_                           [JOHN, WRITE, HOMEWORK]
# 1    003_                 [IX-1P, SEE, JOHN, YESTERDAY, IX]
# 2    004_                 [JOHN, IX-1P, SEE, IX, YESTERDAY]
# 3    005_                                [LOVE, MARY, JOHN]
# 4    006_                            [LOVE, MARY, JOHN, IX]
# 5    008_                              [JOHN, CAN, GO, CAN]
# 6    009_                             [JOHN, CAN, GO1, CAN]
# 7    010_                              [JOHN, CAN, GO, CAN]
# 8    011_                             [JOHN, CAN, GO1, CAN]
# 9    013_                             [JOHN, CAN, GO1, CAN]
# 10   014_                             [JOHN, CAN, GO1, CAN]
# 11   015_                [JOHN, FUTURE, GO2, PARTY, FUTURE]
# 12   016_                           [JOHN, FUTURE1, GO, IX]
# 13   017_                           [JOHN, FUTURE1, GO, IX]
# 14   018_                  [JOHN, IX, HIT, BLAME, FRED, IX]
# 15   019_   [JOHN, FISH, WONT, EAT, BUT, CAN, EAT, CHICKEN]
# 16   020_   [JOHN, FISH, WONT, EAT, BUT, CAN, EAT, CHICKEN]
# 17   022_  [VEGETABLE, CHINA, IX, PEOPLE, PREFER, BROCCOLI]
# 18   023_  [VEGETABLE, CHINA, IX, PEOPLE, PREFER, BROCCOLI]
# 19   024_                          [JOHN, LIKE, IX, IX, IX]
# 20   026_                          [JOHN, LIKE, IX, IX, IX]
# 21   027_                          [JOHN, LIKE, IX, IX, IX]
# 22   029_                          [JOHN, LIKE, IX, IX, IX]
# 23   031_                                 [JOHN, LEAVE, IX]
# 24   032_                                 [JOHN, LEAVE, IX]
# 25   033_                                 [JOHN, LEAVE, IX]
# 26   034_              [JOHN, SAY, MARY, IX-1P, BUY, HOUSE]
# 27   035_           [MARY, VEGETABLE, KNOW, IX, LIKE, CORN]
# 28   037_   [MARY, VEGETABLE, IX-1P, KNOW, IX, LIKE, CORN1]
# 29   038_          [MARY, VEGETABLE, KNOW, IX, LIKE, CORN1]
# ..    ...                                               ...
# 131  163_                                     [WHO, ARRIVE]
# 132  164_                                            [NAME]
# 133  165_                                    [SHOOT, FRANK]
# 134  166_                    [JOHN, IX, SAY-1P, LOVE, MARY]
# 135  168_                                     [JOHN, BLAME]
# 136  169_                     [MARY, BILL, SAY, JOHN, LOVE]
# 137  170_                               [JOHN, MARY, BLAME]
# 138  172_                        [MARY, SELF, PREFER, CORN]
# 139  173_                        [MARY, SELF, PREFER, CORN]
# 140  175_                 [PEOPLE, GROUP, GIVE1, JANA, TOY]
# 141  176_                 [MANY, PEOPLE, GIVE1, JANA, TOY1]
# 142  177_                                [JOHN, LOVE, MARY]
# 143  178_                                    [JOHN, ARRIVE]
# 144  179_                                    [JOHN, ARRIVE]
# 145  180_                                    [JOHN, ARRIVE]
# 146  182_                 [ALL, BOY, GIVE1, TEACHER, APPLE]
# 147  183_                 [ALL, BOY, GIVE1, TEACHER, APPLE]
# 148  185_                       [IX, GIRL, GIVE, JOHN, BOX]
# 149  186_                      [IX, GIRL, GIVE2, JOHN, BOX]
# 150  187_            [TEACHER, GIVE, GIVE, GIVE, BOY, BOOK]
# 151  188_                       [TEACHER, GIVE3, BOY, BOOK]
# 152  190_                       [IX, GIRL, GIVE, JOHN, BOX]
# 153  191_                           [JOHN, GIVE, GIRL, BOX]
# 154  192_                          [JOHN, GIVE3, GIRL, BOX]
# 155  194_                             [JOHN, CAN, GET, CAN]
# 156  195_       [JOHN, NOT, VISIT, MARY, VISIT, MOTHER, IX]
# 157  196_                              [IX, BOOK, PUTASIDE]
# 158  197_                         [JOHN, ARRIVE, NOT, WHAT]
# 159  198_                            [LIKE, CHOCOLATE, WHO]
# 160  200_                          [JOHN, VISIT, WHO, WHAT]
#
# [161 rows x 2 columns]

# %%
df_words
# Out:
#               word   id  Frecuency
# 0             john    0        113
# 1               ix    1         52
# 2             mary    2         37
# 3             what    3         26
# 4              who    4         25
# 5              buy    5         22
# 6             book    6         18
# 7             give    7         18
# 8              can    8         17
# 9               go    9         17
# 10          future   10         17
# 11             car   11         16
# 12          arrive   12         15
# 13            love   13         14
# 14            like   14         12
# 15          should   15         12
# 16            poss   16         12
# 17           visit   17         11
# 18       yesterday   18         10
# 19           house   19         10
# 20             not   20         10
# 21   something-one   21         10
# 22             see   22          9
# 23          prefer   23          7
# 24           woman   24          7
# 25       vegetable   25          6
# 26            bill   26          6
# 27           ix-1p   27          5
# 28             eat   28          5
# 29            corn   29          5
# ..             ...  ...        ...
# 73            jana   73          2
# 74             toy   74          2
# 75             all   75          2
# 76           write   76          1
# 77        homework   77          1
# 78           party   78          1
# 79             hit   79          1
# 80            fred   80          1
# 81            past   81          1
# 82            live   82          1
# 83         chicago   83          1
# 84        tomorrow   84          1
# 85       next-week   85          1
# 86       last-week   86          1
# 87             ann   87          1
# 88            find   88          1
# 89      search-for   89          1
# 90             leg   90          1
# 91          friend   91          1
# 92           candy   92          1
# 93             old   93          1
# 94          borrow   94          1
# 95          potato   95          1
# 96            name   96          1
# 97           shoot   97          1
# 98          say-1p   98          1
# 99           group   99          1
# 100           many  100          1
# 101            get  101          1
# 102       putaside  102          1
#
# [103 rows x 3 columns]

# %%
df_wer = pd.DataFrame(columns=["video","training","predicted","wer"])
for i in range (len(df_training)):
    video = df_training.video.iloc[i]
    ref = df_training.orth.iloc[i]
    ev = df_jeff.orth.iloc[i]
    WER = wer(ref,ev)
    df_wer.at[i,"video"] = video
    df_wer.at[i,"training"] = ref
    df_wer.at[i,"predicted"] = ev
    df_wer.at[i,"wer"] = WER

# %%
df_wer[df_wer["wer"] < 1]
# Out:
#    video                                  training  \
# 29  038_  [MARY, VEGETABLE, KNOW, IX, LIKE, CORN1]
#
#                                             predicted       wer
# 29  [MARY, ALL, WONT, SEARCH-FOR, CHICKEN, NEXT-WEEK]  0.833333

# %%
print(df_wer.wer.mean())
# Out:
# 0.9989648033126293
