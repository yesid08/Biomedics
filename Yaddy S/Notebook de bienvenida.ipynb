# %% [markdown]
# ## Bienvenidos!

# %% [markdown]
# En estos notebooks vamos a correr una red neuronal para interpretar texto.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.


from __future__ import print_function
import collections
import math
import tensorflow as tf
import numpy as np
import os
import random
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# %matplotlib inline

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

# skip_window: int : How many words to consider left and right.
def generate_cbow_batch(batch_size, skip_window):
  global data_index
#   assert batch_size % num_skips == 0
#   assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, skip_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
#   buffer = []
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
  for i in range(batch_size):
    batch[i] = list(buffer)[:skip_window] + list(buffer)[skip_window+1:]
    labels[i] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels

# %%
batch,labels = generate_cbow_batch(128,1)

# %%
batch[:10]
# Out:
# array([[5234,   12],
#        [3081,    6],
#        [  12,  195],
#        [   6,    2],
#        [ 195, 3134],
#        [   2,   46],
#        [3134,   59],
#        [  46,  156],
#        [  59,  128],
#        [ 156,  742]])

# %%
labels[:10]
# Out:
# array([[3081],
#        [  12],
#        [   6],
#        [ 195],
#        [   2],
#        [3134],
#        [  46],
#        [  59],
#        [ 156],
#        [ 128]])

# %%
for i in range (np.random.randint(28) , np.random.randint(28)+100 ):
    print ('input: ({},{}) -- label:({})'.format(reverse_dictionary[batch[i,0]], reverse_dictionary[batch[i,1]],
                                                reverse_dictionary[labels[i][0]]))
# Out:
# input: (first,against) -- label:(used)
# input: (used,early) -- label:(against)
# input: (against,working) -- label:(early)
# input: (early,class) -- label:(working)
# input: (working,radicals) -- label:(class)
# input: (class,including) -- label:(radicals)
# input: (radicals,the) -- label:(including)
# input: (including,diggers) -- label:(the)
# input: (the,of) -- label:(diggers)
# input: (diggers,the) -- label:(of)
# input: (of,english) -- label:(the)
# input: (the,revolution) -- label:(english)
# input: (english,and) -- label:(revolution)
# input: (revolution,the) -- label:(and)
# input: (and,sans) -- label:(the)
# input: (the,UNK) -- label:(sans)
# input: (sans,of) -- label:(UNK)
# input: (UNK,the) -- label:(of)
# input: (of,french) -- label:(the)
# input: (the,revolution) -- label:(french)
# input: (french,whilst) -- label:(revolution)
# input: (revolution,the) -- label:(whilst)
# input: (whilst,term) -- label:(the)
# input: (the,is) -- label:(term)
# input: (term,still) -- label:(is)
# input: (is,used) -- label:(still)
# input: (still,in) -- label:(used)
# input: (used,a) -- label:(in)
# input: (in,pejorative) -- label:(a)
# input: (a,way) -- label:(pejorative)
# input: (pejorative,to) -- label:(way)
# input: (way,describe) -- label:(to)
# input: (to,any) -- label:(describe)
# input: (describe,act) -- label:(any)
# input: (any,that) -- label:(act)
# input: (act,used) -- label:(that)
# input: (that,violent) -- label:(used)
# input: (used,means) -- label:(violent)
# input: (violent,to) -- label:(means)
# input: (means,destroy) -- label:(to)
# input: (to,the) -- label:(destroy)
# input: (destroy,organization) -- label:(the)
# input: (the,of) -- label:(organization)
# input: (organization,society) -- label:(of)
# input: (of,it) -- label:(society)
# input: (society,has) -- label:(it)
# input: (it,also) -- label:(has)
# input: (has,been) -- label:(also)
# input: (also,taken) -- label:(been)
# input: (been,up) -- label:(taken)
# input: (taken,as) -- label:(up)
# input: (up,a) -- label:(as)
# input: (as,positive) -- label:(a)
# input: (a,label) -- label:(positive)
# input: (positive,by) -- label:(label)
# input: (label,self) -- label:(by)
# input: (by,defined) -- label:(self)
# input: (self,anarchists) -- label:(defined)
# input: (defined,the) -- label:(anarchists)
# input: (anarchists,word) -- label:(the)
# input: (the,anarchism) -- label:(word)
# input: (word,is) -- label:(anarchism)
# input: (anarchism,derived) -- label:(is)
# input: (is,from) -- label:(derived)
# input: (derived,the) -- label:(from)
# input: (from,greek) -- label:(the)
# input: (the,without) -- label:(greek)
# input: (greek,archons) -- label:(without)
# input: (without,ruler) -- label:(archons)
# input: (archons,chief) -- label:(ruler)
# input: (ruler,king) -- label:(chief)
# input: (chief,anarchism) -- label:(king)
# input: (king,as) -- label:(anarchism)
# input: (anarchism,a) -- label:(as)
# input: (as,political) -- label:(a)
# input: (a,philosophy) -- label:(political)
# input: (political,is) -- label:(philosophy)
# input: (philosophy,the) -- label:(is)
# input: (is,belief) -- label:(the)
# input: (the,that) -- label:(belief)
# input: (belief,rulers) -- label:(that)
# input: (that,are) -- label:(rulers)
# input: (rulers,unnecessary) -- label:(are)
# input: (are,and) -- label:(unnecessary)
# input: (unnecessary,should) -- label:(and)
# input: (and,be) -- label:(should)
# input: (should,abolished) -- label:(be)
# input: (be,although) -- label:(abolished)
# input: (abolished,there) -- label:(although)
# input: (although,are) -- label:(there)
# input: (there,differing) -- label:(are)
# input: (are,interpretations) -- label:(differing)
# input: (differing,of) -- label:(interpretations)
# input: (interpretations,what) -- label:(of)
# input: (of,this) -- label:(what)
# input: (what,means) -- label:(this)
# input: (this,anarchism) -- label:(means)
# input: (means,also) -- label:(anarchism)
# input: (anarchism,refers) -- label:(also)
# input: (also,to) -- label:(refers)
# input: (refers,related) -- label:(to)
# input: (to,social) -- label:(related)
# input: (related,movements) -- label:(social)
# input: (social,that) -- label:(movements)
# input: (movements,advocate) -- label:(that)
# input: (that,the) -- label:(advocate)
# input: (advocate,elimination) -- label:(the)
# input: (the,of) -- label:(elimination)

# %%
# CBOW model

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  # note the different input dimensions for the CBOW model
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # note the sum over the context embeddings for the CBOW model
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.reduce_sum(embed, 1)

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.776235
# Nearest to in: victors, mulholland, repairing, realaudio, marin, tau, bouvier, mintz,
# Nearest to during: sud, fermium, phillip, skeptic, cer, popularize, zephaniah, conjunctions,
# Nearest to united: arcturus, bipeds, fabian, foxes, motorised, maribor, riordan, budgets,
# Nearest to would: limehouse, forgotten, resident, callet, oust, aedui, transfinite, outbursts,
# Nearest to all: sst, demarcated, reactance, dyslexic, promiscuous, venter, fra, equalized,
# Nearest to however: archived, clerks, emulates, maoist, kaczynski, dil, daggers, muslims,
# Nearest to with: corrective, relax, guises, drowns, khaki, pura, assessing, observer,
# Nearest to history: davidson, enforcers, chogm, ordinations, oppressive, giulia, nitro, erlk,
# Nearest to so: technische, enough, candide, pledging, permanence, spent, kara, decisive,
# Nearest to b: lease, osamu, bears, dolomite, wheeling, labeling, intestine, gok,
# Nearest to seven: wider, kohanim, elders, odegard, blower, widen, tobit, pg,
# Nearest to often: windward, vander, mathbf, quatre, catapults, fletcher, haze, wah,
# Nearest to or: splitflag, signer, infielders, nightingale, dayan, since, proposed, knocks,
# Nearest to his: touchdown, damasus, chichester, elucidated, lithuanian, arabica, coronado, explodes,
# Nearest to an: feet, kidnapped, levels, deceit, until, raining, discoverer, cryonics,
# Nearest to between: hence, tumour, hexagrams, gibbs, perigee, spines, gravitation, avoiding,
# Average loss at step 2000: 4.097091
# Average loss at step 4000: 3.553649
# Average loss at step 6000: 3.390095
# Average loss at step 8000: 3.240086
# Average loss at step 10000: 3.177618
# Nearest to in: on, at, under, with, questionnaire, during, ais, between,
# Nearest to during: in, skeptic, scribe, phillip, fermium, without, jeffersonian, at,
# Nearest to united: universiti, rump, arcturus, above, firearm, lingerie, buggery, hitters,
# Nearest to would: could, can, will, may, should, cannot, might, must,
# Nearest to all: many, several, some, damascus, tumbling, canberra, discern, mingle,
# Nearest to however: but, archived, appendicitis, quay, awacs, manage, aeroplanes, dil,
# Nearest to with: between, in, azeglio, strategy, peek, for, before, by,
# Nearest to history: garnier, etched, hee, enraged, overwhelm, chogm, gyre, lovers,
# Nearest to so: technische, enough, transformations, bolstering, permanence, handlers, dogme, bethesda,
# Nearest to b: d, ligase, iliad, lease, graduates, russcol, tuition, holm,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to often: also, usually, generally, fletcher, sometimes, packard, artaxerxes, sliding,
# Nearest to or: and, than, caspar, precipitate, authoritarianism, warhead, algemeen, troopers,
# Nearest to his: their, her, its, the, my, this, horribly, rpg,
# Nearest to an: levels, interacting, jell, admiration, aunt, bizkit, raining, cryonics,
# Nearest to between: with, kilmer, hence, genocidal, in, genteel, perigee, facilitation,
# Average loss at step 12000: 3.203662
# Average loss at step 14000: 3.149471
# Average loss at step 16000: 3.175457
# Average loss at step 18000: 3.122782
# Average loss at step 20000: 2.988459
# Nearest to in: during, at, of, linda, on, reindeer, revolver, between,
# Nearest to during: in, through, within, throughout, towards, conscientious, across, at,
# Nearest to united: universiti, rump, hashes, larval, firearm, buggery, trailing, strictness,
# Nearest to would: can, could, will, may, should, must, might, cannot,
# Nearest to all: several, many, tumbling, canberra, some, discern, these, those,
# Nearest to however: but, although, that, quay, cessna, noteworthy, patel, dictatorship,
# Nearest to with: between, azeglio, nudes, peek, berger, naghten, appellate, treasures,
# Nearest to history: garnier, testament, summarizes, form, overwhelm, etched, thunder, homomorphisms,
# Nearest to so: dogme, succumbed, enough, bolstering, transformations, provencal, caricatures, pullback,
# Nearest to b: d, graduates, f, russcol, gladly, holm, utensils, ins,
# Nearest to seven: eight, six, five, nine, four, zero, three, two,
# Nearest to often: usually, sometimes, generally, also, widely, commonly, frequently, still,
# Nearest to or: and, than, segr, tianjin, kanem, sociale, deprive, woolen,
# Nearest to his: their, her, its, my, the, your, s, a,
# Nearest to an: gottlob, draining, disagreeable, interacting, coincident, conservatoire, kidnapped, jell,
# Nearest to between: with, johnstone, enemy, hence, drawbacks, among, motorist, grosse,
# Average loss at step 22000: 3.070852
# Average loss at step 24000: 3.033597
# Average loss at step 26000: 3.004687
# Average loss at step 28000: 3.025052
# Average loss at step 30000: 3.006165
# Nearest to in: during, within, on, of, from, throughout, until, at,
# Nearest to during: in, after, within, before, under, throughout, when, towards,
# Nearest to united: rump, universiti, fenrir, buggery, hashes, thereupon, door, same,
# Nearest to would: could, will, can, may, should, must, might, cannot,
# Nearest to all: both, these, some, every, many, any, tumbling, various,
# Nearest to however: but, although, that, though, where, when, since, which,
# Nearest to with: between, handsome, azeglio, licensing, peek, midwives, dez, nudes,
# Nearest to history: story, hating, pascal, name, postcolonial, risk, khaganate, testament,
# Nearest to so: succumbed, enough, dk, provencal, dogme, scotsman, if, less,
# Nearest to b: d, f, pavia, graduates, holm, lindh, appellate, spoofing,
# Nearest to seven: eight, nine, six, four, five, zero, three, two,
# Nearest to often: usually, sometimes, generally, commonly, widely, still, frequently, now,
# Nearest to or: and, than, sociale, tianjin, mercenary, dew, antigonus, breathes,
# Nearest to his: her, their, its, my, your, our, the, horribly,
# Nearest to an: aunt, draining, coincident, alois, anticipates, conservatoire, interacting, jell,
# Nearest to between: with, among, hence, mujahidin, rudimentary, countable, enemy, cryptographic,
# Average loss at step 32000: 2.827696
# Average loss at step 34000: 2.959669
# Average loss at step 36000: 2.950257
# Average loss at step 38000: 2.937980
# Average loss at step 40000: 2.929285
# Nearest to in: during, within, throughout, from, on, among, including, until,
# Nearest to during: in, after, throughout, towards, through, when, under, before,
# Nearest to united: same, caribbean, rump, universiti, thereupon, sachsen, buggery, trailing,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to all: both, every, many, any, tumbling, some, discern, various,
# Nearest to however: but, although, that, though, cases, etc, where, while,
# Nearest to with: between, azeglio, when, peek, ascetic, naghten, while, frey,
# Nearest to history: story, postcolonial, list, yaoi, range, hating, pascal, chording,
# Nearest to so: succumbed, severly, too, enough, flux, deporting, if, protracted,
# Nearest to b: d, f, pavia, holm, graduates, meme, vert, m,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to often: usually, sometimes, commonly, generally, frequently, now, still, widely,
# Nearest to or: and, than, while, sociale, discontinuity, tianjin, earthen, fula,
# Nearest to his: her, their, my, its, your, our, the, depressants,
# Nearest to an: jell, coincident, admiration, kidnapped, stretched, suppressor, cii, tribulations,
# Nearest to between: with, among, within, drawbacks, through, from, perigee, frail,
# Average loss at step 42000: 2.954923
# Average loss at step 44000: 2.961839
# Average loss at step 46000: 2.908549
# Average loss at step 48000: 2.868539
# Average loss at step 50000: 2.848715
# Nearest to in: during, within, from, on, at, throughout, litani, of,
# Nearest to during: in, after, when, throughout, before, within, under, while,
# Nearest to united: rump, same, caribbean, universiti, thereupon, larval, buggery, confederate,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to all: several, many, every, both, some, various, these, those,
# Nearest to however: although, but, that, though, cases, where, testable, since,
# Nearest to with: between, including, decibel, azeglio, pcc, assessing, frey, anarchic,
# Nearest to history: list, story, postcolonial, form, hating, music, portion, greeting,
# Nearest to so: too, then, indeed, succumbed, flux, enough, severly, sometimes,
# Nearest to b: d, pavia, c, holm, graham, vermeer, injustice, tuition,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to often: usually, sometimes, commonly, generally, now, frequently, typically, widely,
# Nearest to or: and, than, while, but, discontinuity, cryoprotectant, sociale, tianjin,
# Nearest to his: her, their, my, its, your, our, the, nene,
# Nearest to an: draining, jell, suppressor, raining, kidnapped, xerox, deux, bizkit,
# Nearest to between: with, among, within, rudimentary, drawbacks, grosse, into, hydrothermal,
# Average loss at step 52000: 2.883670
# Average loss at step 54000: 2.861528
# Average loss at step 56000: 2.858237
# Average loss at step 58000: 2.756165
# Average loss at step 60000: 2.828313
# Nearest to in: during, within, at, on, under, among, from, concerning,
# Nearest to during: after, in, when, throughout, within, under, through, including,
# Nearest to united: rump, confederate, baltic, same, larval, thereupon, covariance, universiti,
# Nearest to would: will, could, can, should, may, might, must, cannot,
# Nearest to all: many, both, every, various, several, any, these, impede,
# Nearest to however: but, although, that, though, while, where, when, especially,
# Nearest to with: between, among, by, pcc, peek, wane, frey, berger,
# Nearest to history: story, list, science, postcolonial, practice, greeting, yucat, bipolar,
# Nearest to so: too, enough, succumbed, indeed, brevity, sometimes, how, severly,
# Nearest to b: d, c, holm, r, pavia, f, activator, vermeer,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to often: usually, sometimes, commonly, generally, typically, frequently, widely, now,
# Nearest to or: and, than, sociale, while, copa, though, partnering, moguls,
# Nearest to his: her, their, its, my, your, our, the, whose,
# Nearest to an: suppressor, draining, disagreeable, regulatory, anticipates, kidnapped, jell, microcontrollers,
# Nearest to between: among, within, with, into, rudimentary, drawbacks, ass, during,
# Average loss at step 62000: 2.832255
# Average loss at step 64000: 2.770066
# Average loss at step 66000: 2.764705
# Average loss at step 68000: 2.714919
# Average loss at step 70000: 2.776400
# Nearest to in: within, during, on, until, under, at, throughout, near,
# Nearest to during: under, throughout, after, in, when, within, at, through,
# Nearest to united: caribbean, rump, communist, confederate, thereupon, widowers, ethicists, baltic,
# Nearest to would: will, could, might, should, must, can, may, cannot,
# Nearest to all: both, many, various, every, these, tumbling, achilles, discern,
# Nearest to however: but, although, though, while, that, when, especially, limp,
# Nearest to with: between, while, when, peek, azeglio, giving, nudes, forks,
# Nearest to history: list, story, science, title, pascal, reconquista, suffix, lists,
# Nearest to so: too, succumbed, enough, sometimes, indeed, thus, missed, very,
# Nearest to b: d, holm, vermeer, ciphertext, metabolize, coogan, tuition, passant,
# Nearest to seven: six, eight, nine, five, three, four, zero, two,
# Nearest to often: sometimes, commonly, usually, generally, typically, frequently, widely, now,
# Nearest to or: and, than, hamsun, tianjin, cyclotron, though, sociale, woolen,
# Nearest to his: her, their, its, my, our, your, whose, the,
# Nearest to an: draining, suppressor, raining, jell, coincident, fully, microcontrollers, retroflex,
# Nearest to between: within, among, with, during, ass, grosse, lycia, into,
# Average loss at step 72000: 2.796266
# Average loss at step 74000: 2.647592
# Average loss at step 76000: 2.804164
# Average loss at step 78000: 2.821847
# Average loss at step 80000: 2.781802
# Nearest to in: during, within, at, on, throughout, through, near, until,
# Nearest to during: throughout, after, in, when, despite, before, under, through,
# Nearest to united: caribbean, communist, ribeira, confederate, rump, same, baltic, ethicists,
# Nearest to would: will, could, might, should, must, can, may, cannot,
# Nearest to all: both, many, every, various, several, any, vainly, impede,
# Nearest to however: but, although, though, that, especially, used, until, scribe,
# Nearest to with: between, by, assessing, falco, peek, handsome, dez, azeglio,
# Nearest to history: list, topics, science, middle, hildegard, geography, pascal, brunt,
# Nearest to so: too, missed, how, indeed, enough, very, succumbed, blackadder,
# Nearest to b: d, holm, pavia, vermeer, r, c, goetz, raids,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, now, widely,
# Nearest to or: and, than, tianjin, sociale, though, norte, pointer, spinner,
# Nearest to his: her, their, my, your, its, our, whose, the,
# Nearest to an: draining, kidnapped, suppressor, microcontrollers, raining, disagreeable, coincident, diefenbaker,
# Nearest to between: among, within, with, drawbacks, rudimentary, grosse, around, ass,
# Average loss at step 82000: 2.670162
# Average loss at step 84000: 2.768420
# Average loss at step 86000: 2.731570
# Average loss at step 88000: 2.746568
# Average loss at step 90000: 2.733719
# Nearest to in: during, within, on, throughout, near, through, at, until,
# Nearest to during: throughout, in, after, despite, at, when, under, before,
# Nearest to united: caribbean, communist, confederate, baltic, mediterranean, rump, ethicists, signed,
# Nearest to would: could, will, might, should, can, must, may, cannot,
# Nearest to all: both, various, many, every, some, several, most, vainly,
# Nearest to however: but, although, though, that, nevertheless, when, while, chooses,
# Nearest to with: between, berger, nudes, dez, peek, forks, azeglio, bubi,
# Nearest to history: list, hildegard, postcolonial, greeting, because, cy, brunt, congo,
# Nearest to so: too, indeed, enough, missed, clothing, bolstering, succumbed, sometimes,
# Nearest to b: d, c, pavia, f, holm, r, gerund, goetz,
# Nearest to seven: six, eight, nine, four, five, three, zero, two,
# Nearest to often: usually, generally, sometimes, commonly, typically, frequently, traditionally, now,
# Nearest to or: and, than, but, though, sociale, tianjin, hamsun, cockney,
# Nearest to his: her, their, my, your, our, its, whose, the,
# Nearest to an: draining, kidnapped, coincident, jell, disagreeable, raining, lemass, suppressor,
# Nearest to between: among, within, with, drawbacks, rudimentary, around, grosse, bolivian,
# Average loss at step 92000: 2.679807
# Average loss at step 94000: 2.727975
# Average loss at step 96000: 2.701580
# Average loss at step 98000: 2.366790
# Average loss at step 100000: 2.398805
# Nearest to in: during, within, at, near, throughout, around, where, until,
# Nearest to during: at, throughout, in, despite, after, under, before, around,
# Nearest to united: caribbean, rump, arab, widowers, ethicists, confederate, mediterranean, ribeira,
# Nearest to would: will, could, might, should, must, can, may, cannot,
# Nearest to all: both, various, many, several, every, some, these, numerous,
# Nearest to however: although, but, though, while, when, since, furthermore, that,
# Nearest to with: between, by, when, assessing, falco, nudes, taland, peek,
# Nearest to history: list, contemporary, version, greeting, life, practice, modern, brunt,
# Nearest to so: too, indeed, thus, very, enough, brevity, overlooks, sometimes,
# Nearest to b: d, tl, holm, coogan, gladly, metabolize, nihon, gerund,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to often: generally, sometimes, usually, commonly, frequently, typically, still, now,
# Nearest to or: and, than, tianjin, garry, heliports, nor, though, incubus,
# Nearest to his: her, their, my, its, your, our, the, whose,
# Nearest to an: suppressor, draining, coincident, raining, bizkit, jell, deux, cii,
# Nearest to between: among, with, within, drawbacks, rudimentary, around, grosse, along,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
