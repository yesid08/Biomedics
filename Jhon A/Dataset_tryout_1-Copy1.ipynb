# %%
import tensorflow as tf
import collections
import numpy as np
import pandas as pd
import random
import math
from sklearn.manifold import TSNE
from matplotlib import pylab

# %%
def create_dataset(trainFileName, TestFileName):
    train_data = pd.read_csv(trainFileName,delimiter=";")
    test_data  = pd.read_csv(testFileName,delimiter=";")
    sentences_train = [sentence[:len(sentence) -1 ] for sentence in train_data.translation]
    sentences_test = [sentence[:len(sentence) -1 ] for sentence in train_data.translation]
    sentences = sentences_train + sentences_test
    words = []
    for sentence in sentences:
        sentence = sentence.split()
        for  i in range (len(sentence)):
            word = sentence[i]
            word = str.lower(word)
            word = word.rstrip(",")
            word = word.rstrip(".")
            word = word.rstrip("?")
            word = word.rstrip(";")
            words.append(word)
    del train_data
    del sentences
    del sentences_test
    del sentences_train
    return words

# %%
trainFileName = 'train.sentences.pronunciations.multi.translations.csv'
testFileName = "test.sentences.multi.translations.csv" 
words = create_dataset(trainFileName, testFileName)
vocabulary_size = len(words)
print("El vocabulario de este dataset consiste en un total de {} palabras diferentes".format(vocabulary_size))
display(collections.Counter(words).most_common())
# Out:
# El vocabulario de este dataset consiste en un total de 1756 palabras diferentes
# [('john', 200),
#  ('the', 156),
#  ('mary', 74),
#  ('a', 42),
#  ('in', 40),
#  ('is', 40),
#  ('to', 36),
#  ('book', 36),
#  ('who', 36),
#  ('future', 34),
#  ('car', 32),
#  ('go', 30),
#  ('loves', 28),
#  ('there', 26),
#  ('that', 26),
#  ('buy', 26),
#  ('arrives', 26),
#  ('will', 24),
#  ('visit', 24),
#  ("john's", 24),
#  ('gives', 24),
#  ('likes', 22),
#  ('yesterday', 20),
#  ('house', 20),
#  ('what', 20),
#  ('one', 20),
#  ('for', 18),
#  ('should', 18),
#  ('can', 16),
#  ("won't", 14),
#  ('visits', 14),
#  ('new', 14),
#  ('woman', 14),
#  ('bill', 14),
#  ('sure', 12),
#  ('vegtables', 12),
#  ('he', 12),
#  ('i', 10),
#  ('corn', 10),
#  ('prefers', 10),
#  ('has', 10),
#  ('buys', 10),
#  ('an', 10),
#  ('apple', 10),
#  ('girl', 10),
#  ('box', 10),
#  ('blames', 8),
#  ('people', 8),
#  ('this', 8),
#  ('and', 8),
#  ('not', 8),
#  ('here', 8),
#  ('breaks', 8),
#  ('down', 8),
#  ('sue', 8),
#  ('blue', 8),
#  ('bought', 8),
#  ('really', 8),
#  ('give', 8),
#  ('teacher', 8),
#  ('his', 6),
#  ('visited', 6),
#  ('eat', 6),
#  ('leaves', 6),
#  ('tells', 6),
#  ('over', 6),
#  ("doesn't", 6),
#  ('chocolate', 6),
#  ('some', 6),
#  ("frank's", 6),
#  ('student', 6),
#  ('videotape', 6),
#  ('it', 6),
#  ('told', 6),
#  ('throws', 6),
#  ('on', 6),
#  ('fish', 4),
#  ('but', 4),
#  ('eats', 4),
#  ('chicken', 4),
#  ('china', 4),
#  ('prefer', 4),
#  ('broccoli', 4),
#  ('knows', 4),
#  ('thinks', 4),
#  ('him', 4),
#  ('decides', 4),
#  ('movie', 4),
#  ('wants', 4),
#  ('sell', 4),
#  ('week', 4),
#  ('york', 4),
#  ('be', 4),
#  ('finish', 4),
#  ('reading', 4),
#  ('somebody', 4),
#  ('brother', 4),
#  ('man', 4),
#  ('coat', 4),
#  ('which', 4),
#  ('someones', 4),
#  ('stolen', 4),
#  ('mother', 4),
#  ('whom', 4),
#  ('says', 4),
#  ('herself', 4),
#  ('jana', 4),
#  ('toys', 4),
#  ('all', 4),
#  ('boys', 4),
#  ('boy', 4),
#  ('writes', 2),
#  ('homework', 2),
#  ('party', 2),
#  ('fred', 2),
#  ('being', 2),
#  ('hit', 2),
#  ('know', 2),
#  ('lived', 2),
#  ('chicago', 2),
#  ('next', 2),
#  ('last', 2),
#  ('ann', 2),
#  ('like', 2),
#  ('find', 2),
#  ('owns', 2),
#  ('searches', 2),
#  ('owner', 2),
#  ('of', 2),
#  ('leg', 2),
#  ('friend', 2),
#  ('candy', 2),
#  ('old', 2),
#  ('was', 2),
#  ('sold', 2),
#  ('reads', 2),
#  ('borrows', 2),
#  ('someone', 2),
#  ('potatoes', 2),
#  ('name', 2),
#  ('frank', 2),
#  ('shot', 2),
#  ('she', 2),
#  ('many', 2),
#  ('get', 2),
#  ('puts', 2),
#  ('aside', 2),
#  ('arrive', 2)]

# %%
def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1 ))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print(type(data),type(count),type(dictionary),type(reverse_dictionary))
# Out:
# <class 'list'> <class 'list'> <class 'dict'> <class 'dict'>

# %%
data_index = 0
batch_size = 32
# skip_window: int : How many words to consider left and right.
def generate_cbow_batch(batch_size, skip_window):
  global data_index
#   assert batch_size % num_skips == 0
#   assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, skip_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
#   buffer = []
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
  for i in range(batch_size):
    batch[i] = list(buffer)[:skip_window] + list(buffer)[skip_window+1:]
    labels[i] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels
batch,labels = generate_cbow_batch(10,1)
# print (len(batch))
# Out:
# 10

# %%
for i in range (0 , 10 ):
    print ('input: ({0},{1}) -- label:({2}) -- sentence: {0} {2} {1}'.format(reverse_dictionary[batch[i,0]],
                                                                               reverse_dictionary[batch[i,1]],
                                                                               reverse_dictionary[labels[i][0]]))
# Out:
# input: (john,his) -- label:(UNK) -- sentence: john UNK his
# input: (UNK,UNK) -- label:(his) -- sentence: UNK his UNK
# input: (his,i) -- label:(UNK) -- sentence: his UNK i
# input: (UNK,visited) -- label:(i) -- sentence: UNK i visited
# input: (i,john) -- label:(visited) -- sentence: i visited john
# input: (visited,there) -- label:(john) -- sentence: visited john there
# input: (john,yesterday) -- label:(there) -- sentence: john there yesterday
# input: (there,i) -- label:(yesterday) -- sentence: there yesterday i
# input: (yesterday,visited) -- label:(i) -- sentence: yesterday i visited
# input: (i,john) -- label:(visited) -- sentence: i visited john

# %%
# CBOW model
embedding_size = 640 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 30 # Random set of words to evaluate similarity on.
valid_window = 30 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 30 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  # note the different input dimensions for the CBOW model
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # note the sum over the context embeddings for the CBOW model
  #Búsqueda de los parámetros dados en el training batch
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  #Realiza una suma a través de las filas
  embed = tf.reduce_sum(embed, 1)

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 4.071740
# Nearest to car: told, coat, some, new, student, buy, who, teacher,
# Nearest to will: mary, and, future, what, vegtables, him, breaks, in,
# Nearest to arrives: in, will, gives, he, buy, woman, yesterday, student,
# Nearest to future: on, will, student, he, yesterday, not, eats, chicken,
# Nearest to can: told, book, decides, in, who, sell, finish, woman,
# Nearest to visit: eat, doesn't, girl, woman, prefers, china, visits, apple,
# Nearest to yesterday: him, john's, brother, man, decides, woman, it, girl,
# Nearest to mary: will, i, throws, but, should, what, chocolate, book,
# Nearest to for: prefer, to, knows, give, fish, over, reading, that,
# Nearest to loves: book, eat, knows, girl, one, there, coat, and,
# Nearest to book: loves, can, sell, he, decides, fish, mary, the,
# Nearest to should: student, throws, the, over, wants, give, mary, one,
# Nearest to that: what, sell, box, videotape, throws, a, chocolate, his,
# Nearest to john: won't, tells, thinks, blue, he, and, student, doesn't,
# Nearest to a: but, thinks, broccoli, teacher, that, coat, leaves, doesn't,
# Nearest to what: that, bought, breaks, but, i, really, will, mary,
# Nearest to who: can, buys, house, car, yesterday, gives, box, future,
# Nearest to john's: yesterday, be, doesn't, leaves, sue, breaks, this, him,
# Nearest to go: brother, not, tells, house, told, what, corn, here,
# Nearest to in: arrives, can, sue, brother, it, will, the, buy,
# Nearest to one: decides, knows, blames, bill, loves, china, should, here,
# Nearest to UNK: vegtables, some, down, tells, china, can, chocolate, decides,
# Nearest to the: videotape, teacher, should, people, visits, decides, eat, in,
# Nearest to buy: i, really, it, car, breaks, arrives, in, somebody,
# Nearest to to: gives, give, teacher, for, sure, his, new, prefers,
# Nearest to likes: leaves, week, chocolate, box, eats, house, knows, there,
# Nearest to there: but, visits, frank's, give, loves, gives, blames, he,
# Nearest to gives: to, visits, decides, house, but, arrives, who, there,
# Nearest to house: chicken, gives, who, go, corn, can, frank's, likes,
# Nearest to is: has, china, prefers, movie, but, reading, sell, down,
# Average loss at step 2000: 2.989349
# Average loss at step 4000: 0.710712
# Average loss at step 6000: 0.605687
# Average loss at step 8000: 0.543949
# Average loss at step 10000: 0.509015
# Nearest to car: there, what, future, who, mary, it, give, student,
# Nearest to will: gives, likes, should, really, loves, won't, tells, blames,
# Nearest to arrives: there, future, prefers, house, likes, gives, has, blames,
# Nearest to future: there, arrives, book, car, it, house, gives, box,
# Nearest to can: should, prefers, really, that, his, is, blames, doesn't,
# Nearest to visit: buy, prefers, loves, go, likes, finish, blames, to,
# Nearest to yesterday: give, bill, john's, for, in, blames, prefers, people,
# Nearest to mary: what, who, china, car, UNK, future, book, this,
# Nearest to for: i, bill, give, yesterday, john's, he, apple, book,
# Nearest to loves: likes, prefers, blames, visits, is, will, gives, visit,
# Nearest to book: videotape, in, man, UNK, it, future, box, vegtables,
# Nearest to should: gives, will, can, really, down, prefers, likes, won't,
# Nearest to that: his, who, to, will, and, what, vegtables, blames,
# Nearest to john: here, who, sue, really, breaks, week, that, has,
# Nearest to a: new, visits, visit, blue, tells, loves, some, be,
# Nearest to what: mary, car, chocolate, that, one, he, him, will,
# Nearest to who: mary, john, that, car, here, future, not, what,
# Nearest to john's: yesterday, for, in, give, bill, i, people, it,
# Nearest to go: buy, visit, finish, visits, leaves, be, book, really,
# Nearest to in: give, yesterday, john's, book, is, box, people, videotape,
# Nearest to one: vegtables, videotape, girl, woman, man, teacher, and, sell,
# Nearest to UNK: box, book, vegtables, new, videotape, woman, it, mary,
# Nearest to the: give, people, new, here, prefers, for, he, not,
# Nearest to buy: visit, go, to, not, finish, new, man, likes,
# Nearest to to: buy, visit, vegtables, videotape, is, that, frank's, sell,
# Nearest to likes: loves, gives, will, prefers, won't, visits, visit, leaves,
# Nearest to there: car, future, arrives, house, bill, bought, not, really,
# Nearest to gives: will, likes, should, loves, won't, down, leaves, buys,
# Nearest to house: there, student, his, give, arrives, future, here, apple,
# Nearest to is: loves, prefers, blames, in, he, to, yesterday, visit,
# Average loss at step 12000: 0.483143
# Average loss at step 14000: 0.467105
# Average loss at step 16000: 0.455071
# Average loss at step 18000: 0.446876
# Average loss at step 20000: 0.433587
# Nearest to car: there, what, future, mary, who, it, arrives, house,
# Nearest to will: gives, likes, should, really, won't, blames, loves, prefers,
# Nearest to arrives: future, there, prefers, house, car, give, here, loves,
# Nearest to future: arrives, there, car, house, it, book, gives, box,
# Nearest to can: should, really, his, prefers, doesn't, is, blames, apple,
# Nearest to visit: prefers, buy, finish, loves, likes, blames, go, new,
# Nearest to yesterday: give, john's, bill, in, for, blames, prefers, people,
# Nearest to mary: what, who, car, future, china, that, should, UNK,
# Nearest to for: bill, i, give, john's, he, yesterday, it, book,
# Nearest to loves: likes, blames, prefers, visits, is, gives, visit, will,
# Nearest to book: videotape, in, for, box, vegtables, new, not, man,
# Nearest to should: gives, will, can, really, down, won't, likes, to,
# Nearest to that: his, will, who, to, what, and, corn, future,
# Nearest to john: who, here, sue, really, he, week, breaks, chocolate,
# Nearest to a: new, visits, visit, tells, some, blue, UNK, told,
# Nearest to what: mary, car, chocolate, he, this, that, somebody, one,
# Nearest to who: john, mary, car, here, that, has, his, not,
# Nearest to john's: yesterday, in, for, give, bill, i, people, doesn't,
# Nearest to go: buy, visit, visits, finish, book, new, leaves, sure,
# Nearest to in: give, john's, yesterday, book, is, box, videotape, people,
# Nearest to one: videotape, vegtables, girl, teacher, woman, man, and, sell,
# Nearest to UNK: vegtables, book, box, new, it, videotape, one, future,
# Nearest to the: people, give, new, book, i, john's, here, for,
# Nearest to buy: visit, finish, to, go, not, new, likes, videotape,
# Nearest to to: buy, should, visit, is, not, corn, videotape, that,
# Nearest to likes: loves, will, prefers, gives, visit, visits, won't, blames,
# Nearest to there: car, future, arrives, house, bill, people, bought, really,
# Nearest to gives: will, should, likes, won't, down, loves, an, doesn't,
# Nearest to house: student, there, future, arrives, here, give, his, apple,
# Nearest to is: loves, prefers, blames, in, yesterday, he, to, give,
# Average loss at step 22000: 0.428334
# Average loss at step 24000: 0.428370
# Average loss at step 26000: 0.419821
# Average loss at step 28000: 0.415268
# Average loss at step 30000: 0.406766
# Nearest to car: there, what, future, who, mary, it, give, house,
# Nearest to will: gives, should, likes, really, won't, blames, an, tells,
# Nearest to arrives: future, there, house, prefers, here, give, car, likes,
# Nearest to future: arrives, there, house, it, car, book, people, here,
# Nearest to can: should, really, his, doesn't, prefers, student, apple, is,
# Nearest to visit: prefers, finish, buy, likes, blames, new, loves, go,
# Nearest to yesterday: give, john's, bill, blames, for, in, people, prefers,
# Nearest to mary: what, who, car, future, china, should, will, really,
# Nearest to for: bill, i, give, he, yesterday, john's, it, book,
# Nearest to loves: likes, blames, prefers, visits, is, doesn't, gives, won't,
# Nearest to book: for, in, videotape, not, box, give, future, vegtables,
# Nearest to should: will, gives, really, can, down, to, an, won't,
# Nearest to that: his, will, who, to, what, should, down, corn,
# Nearest to john: who, here, he, really, what, that, sue, week,
# Nearest to a: new, visits, visit, tells, some, for, has, blue,
# Nearest to what: car, mary, chocolate, that, he, who, somebody, john,
# Nearest to who: john, mary, here, car, that, has, not, what,
# Nearest to john's: yesterday, in, give, for, people, doesn't, bill, i,
# Nearest to go: buy, visit, visits, finish, corn, book, there, videotape,
# Nearest to in: give, john's, yesterday, book, people, is, videotape, box,
# Nearest to one: videotape, vegtables, girl, teacher, woman, and, man, UNK,
# Nearest to UNK: vegtables, box, book, videotape, one, it, in, future,
# Nearest to the: give, people, i, new, book, john's, for, here,
# Nearest to buy: visit, finish, go, new, to, videotape, likes, not,
# Nearest to to: should, buy, that, will, his, is, down, visit,
# Nearest to likes: loves, will, gives, prefers, visit, won't, blames, visits,
# Nearest to there: car, future, arrives, house, bill, people, prefers, not,
# Nearest to gives: will, likes, should, down, won't, loves, doesn't, an,
# Nearest to house: student, future, there, here, arrives, give, his, car,
# Nearest to is: loves, prefers, blames, in, yesterday, tells, to, give,
# Average loss at step 32000: 0.405598
# Average loss at step 34000: 0.402443
# Average loss at step 36000: 0.395899
# Average loss at step 38000: 0.394809
# Average loss at step 40000: 0.394752
# Nearest to car: there, what, future, who, mary, house, it, arrives,
# Nearest to will: gives, should, likes, won't, really, an, blames, prefers,
# Nearest to arrives: future, there, house, here, prefers, car, give, loves,
# Nearest to future: arrives, there, house, it, car, here, book, box,
# Nearest to can: should, doesn't, really, his, prefers, student, apple, is,
# Nearest to visit: finish, prefers, buy, likes, new, blames, loves, go,
# Nearest to yesterday: give, john's, bill, blames, in, for, people, prefers,
# Nearest to mary: what, who, car, future, china, should, book, this,
# Nearest to for: bill, he, i, give, john's, yesterday, book, it,
# Nearest to loves: blames, likes, prefers, visits, doesn't, is, won't, gives,
# Nearest to book: for, in, give, not, videotape, box, future, vegtables,
# Nearest to should: will, gives, to, down, really, an, won't, can,
# Nearest to that: his, will, who, to, should, what, down, corn,
# Nearest to john: who, here, really, he, what, week, that, sue,
# Nearest to a: new, visits, visit, tells, has, for, some, he,
# Nearest to what: car, mary, that, chocolate, who, he, somebody, corn,
# Nearest to who: john, mary, here, car, that, not, has, what,
# Nearest to john's: yesterday, in, give, for, bill, he, doesn't, people,
# Nearest to go: finish, visit, buy, visits, corn, there, really, book,
# Nearest to in: give, john's, yesterday, book, is, videotape, box, people,
# Nearest to one: videotape, girl, vegtables, teacher, and, UNK, man, woman,
# Nearest to UNK: vegtables, box, book, it, videotape, one, arrives, future,
# Nearest to the: give, people, i, new, book, john's, here, for,
# Nearest to buy: finish, visit, new, to, go, videotape, likes, not,
# Nearest to to: should, will, buy, his, is, that, visit, down,
# Nearest to likes: loves, will, prefers, gives, won't, visit, blames, visits,
# Nearest to there: car, future, arrives, house, bill, people, not, prefers,
# Nearest to gives: will, should, likes, won't, down, loves, doesn't, an,
# Nearest to house: future, student, there, arrives, here, car, give, his,
# Nearest to is: loves, prefers, blames, in, yesterday, to, tells, give,
# Average loss at step 42000: 0.386768
# Average loss at step 44000: 0.389610
# Average loss at step 46000: 0.388068
# Average loss at step 48000: 0.388408
# Average loss at step 50000: 0.384766
# Nearest to car: there, what, future, mary, house, who, it, arrives,
# Nearest to will: gives, should, likes, won't, an, really, blames, down,
# Nearest to arrives: future, there, house, here, prefers, car, give, doesn't,
# Nearest to future: arrives, there, house, it, car, here, book, box,
# Nearest to can: should, doesn't, really, his, prefers, week, student, apple,
# Nearest to visit: finish, prefers, buy, new, likes, blames, loves, visits,
# Nearest to yesterday: give, bill, john's, blames, in, for, is, prefers,
# Nearest to mary: what, car, who, future, china, should, that, this,
# Nearest to for: bill, he, i, student, give, book, john's, visits,
# Nearest to loves: blames, likes, prefers, visits, doesn't, is, won't, gives,
# Nearest to book: in, for, give, not, box, future, videotape, vegtables,
# Nearest to should: will, gives, down, to, really, an, won't, doesn't,
# Nearest to that: his, who, will, to, should, what, down, woman,
# Nearest to john: who, here, really, he, what, week, that, somebody,
# Nearest to a: new, visit, tells, visits, for, some, has, i,
# Nearest to what: car, mary, that, chocolate, corn, he, who, somebody,
# Nearest to who: john, mary, car, here, that, not, has, what,
# Nearest to john's: in, yesterday, give, for, bill, doesn't, he, people,
# Nearest to go: finish, visits, buy, visit, corn, there, videotape, book,
# Nearest to in: give, john's, yesterday, book, is, people, videotape, box,
# Nearest to one: videotape, girl, vegtables, teacher, UNK, and, people, chocolate,
# Nearest to UNK: box, vegtables, videotape, it, one, book, future, arrives,
# Nearest to the: give, people, i, book, new, john's, here, for,
# Nearest to buy: finish, visit, new, to, go, likes, videotape, not,
# Nearest to to: should, buy, woman, will, his, is, not, that,
# Nearest to likes: loves, prefers, will, gives, won't, visit, blames, visits,
# Nearest to there: car, future, arrives, house, people, bill, not, prefers,
# Nearest to gives: will, should, likes, down, won't, an, doesn't, loves,
# Nearest to house: future, student, there, arrives, here, car, his, apple,
# Nearest to is: loves, blames, prefers, yesterday, in, tells, to, give,
# Average loss at step 52000: 0.383377
# Average loss at step 54000: 0.380002
# Average loss at step 56000: 0.376308
# Average loss at step 58000: 0.376846
# Average loss at step 60000: 0.374303
# Nearest to car: there, what, future, mary, house, who, it, arrives,
# Nearest to will: gives, should, likes, won't, an, really, down, blames,
# Nearest to arrives: future, there, here, house, prefers, car, give, UNK,
# Nearest to future: arrives, there, house, it, car, here, book, box,
# Nearest to can: should, doesn't, really, his, week, prefers, student, is,
# Nearest to visit: finish, prefers, buy, new, likes, blames, loves, visits,
# Nearest to yesterday: give, bill, john's, blames, in, is, for, prefers,
# Nearest to mary: what, car, who, future, china, should, sure, week,
# Nearest to for: bill, he, student, i, visits, give, book, john's,
# Nearest to loves: blames, likes, prefers, doesn't, visits, won't, is, gives,
# Nearest to book: in, for, give, not, future, box, it, bill,
# Nearest to should: will, gives, down, to, really, an, won't, doesn't,
# Nearest to that: his, who, will, to, should, what, down, woman,
# Nearest to john: who, here, he, what, really, week, that, somebody,
# Nearest to a: new, visit, tells, visits, for, has, some, i,
# Nearest to what: car, mary, that, who, he, john, chocolate, corn,
# Nearest to who: john, mary, that, here, car, what, not, has,
# Nearest to john's: in, yesterday, give, for, doesn't, bill, people, he,
# Nearest to go: finish, visits, visit, buy, there, corn, videotape, book,
# Nearest to in: give, john's, book, yesterday, is, vegtables, people, box,
# Nearest to one: videotape, vegtables, girl, UNK, teacher, and, people, man,
# Nearest to UNK: it, box, one, videotape, vegtables, book, future, arrives,
# Nearest to the: give, people, i, new, john's, book, for, here,
# Nearest to buy: finish, visit, new, to, videotape, go, likes, not,
# Nearest to to: should, buy, will, his, woman, is, that, down,
# Nearest to likes: loves, prefers, will, gives, won't, visit, blames, tells,
# Nearest to there: car, future, arrives, house, people, bill, not, go,
# Nearest to gives: will, should, likes, down, won't, an, doesn't, loves,
# Nearest to house: future, student, arrives, there, here, car, his, bill,
# Nearest to is: loves, blames, prefers, yesterday, in, tells, to, visit,
# Average loss at step 62000: 0.377268
# Average loss at step 64000: 0.377028
# Average loss at step 66000: 0.372545
# Average loss at step 68000: 0.376098
# Average loss at step 70000: 0.367968
# Nearest to car: there, what, future, house, mary, who, arrives, it,
# Nearest to will: gives, should, won't, likes, an, really, blames, down,
# Nearest to arrives: future, there, here, house, car, prefers, give, UNK,
# Nearest to future: arrives, house, there, it, here, car, book, mary,
# Nearest to can: doesn't, should, really, his, week, prefers, is, give,
# Nearest to visit: finish, prefers, buy, new, likes, blames, loves, visits,
# Nearest to yesterday: bill, give, john's, is, blames, in, for, prefers,
# Nearest to mary: what, who, car, future, china, book, that, corn,
# Nearest to for: bill, he, student, i, give, visits, book, yesterday,
# Nearest to loves: blames, likes, prefers, doesn't, visits, won't, is, tells,
# Nearest to book: in, for, give, not, bill, future, it, UNK,
# Nearest to should: will, gives, down, to, won't, an, really, doesn't,
# Nearest to that: his, who, will, what, to, should, down, woman,
# Nearest to john: who, here, what, he, week, really, that, somebody,
# Nearest to a: new, visit, tells, visits, for, has, i, some,
# Nearest to what: car, mary, that, who, corn, chocolate, he, john,
# Nearest to who: john, mary, here, that, car, not, what, future,
# Nearest to john's: in, give, yesterday, bill, doesn't, for, he, people,
# Nearest to go: finish, visits, visit, buy, there, videotape, corn, new,
# Nearest to in: give, john's, book, yesterday, is, vegtables, box, videotape,
# Nearest to one: videotape, girl, vegtables, UNK, teacher, people, and, chocolate,
# Nearest to UNK: it, box, videotape, book, one, vegtables, future, arrives,
# Nearest to the: give, people, i, new, john's, book, bill, here,
# Nearest to buy: finish, visit, new, to, go, likes, videotape, corn,
# Nearest to to: should, his, will, woman, buy, is, that, not,
# Nearest to likes: loves, prefers, will, gives, won't, visit, blames, visits,
# Nearest to there: car, future, arrives, house, people, bill, go, not,
# Nearest to gives: will, should, won't, likes, down, an, doesn't, loves,
# Nearest to house: future, arrives, student, there, car, here, his, bill,
# Nearest to is: loves, blames, yesterday, prefers, in, tells, to, visit,
# Average loss at step 72000: 0.373572
# Average loss at step 74000: 0.370123
# Average loss at step 76000: 0.369321
# Average loss at step 78000: 0.365644
# Average loss at step 80000: 0.364296
# Nearest to car: what, there, future, house, mary, who, arrives, it,
# Nearest to will: gives, should, won't, likes, an, really, down, blames,
# Nearest to arrives: future, here, there, house, car, prefers, doesn't, give,
# Nearest to future: arrives, house, there, here, it, car, mary, book,
# Nearest to can: doesn't, should, really, his, week, is, prefers, give,
# Nearest to visit: finish, buy, prefers, new, likes, blames, loves, visits,
# Nearest to yesterday: give, bill, john's, is, blames, for, in, prefers,
# Nearest to mary: what, car, who, future, china, book, week, sure,
# Nearest to for: bill, he, student, i, give, visits, book, yesterday,
# Nearest to loves: likes, blames, prefers, doesn't, visits, won't, is, tells,
# Nearest to book: give, in, for, not, bill, future, box, it,
# Nearest to should: will, gives, down, to, an, won't, really, doesn't,
# Nearest to that: his, who, will, what, should, down, to, woman,
# Nearest to john: who, here, what, he, week, really, somebody, that,
# Nearest to a: new, tells, visit, for, visits, i, he, prefers,
# Nearest to what: car, mary, that, who, corn, john, he, chocolate,
# Nearest to who: john, mary, that, here, car, not, what, future,
# Nearest to john's: in, yesterday, give, bill, doesn't, for, he, people,
# Nearest to go: finish, visits, buy, visit, there, corn, videotape, book,
# Nearest to in: give, john's, book, yesterday, vegtables, is, people, videotape,
# Nearest to one: videotape, girl, vegtables, UNK, teacher, people, and, sell,
# Nearest to UNK: it, box, one, videotape, vegtables, book, future, arrives,
# Nearest to the: give, people, i, john's, new, book, bill, for,
# Nearest to buy: finish, visit, new, likes, go, to, videotape, corn,
# Nearest to to: should, will, woman, his, is, buy, not, down,
# Nearest to likes: loves, prefers, will, gives, won't, visit, blames, visits,
# Nearest to there: car, future, arrives, house, people, bill, go, not,
# Nearest to gives: will, should, won't, down, likes, an, doesn't, loves,
# Nearest to house: future, arrives, student, there, car, here, his, bill,
# Nearest to is: yesterday, loves, blames, prefers, tells, in, to, visit,
# Average loss at step 82000: 0.365781
# Average loss at step 84000: 0.368060
# Average loss at step 86000: 0.366807
# Average loss at step 88000: 0.364146
# Average loss at step 90000: 0.362434
# Nearest to car: what, there, future, house, mary, arrives, his, who,
# Nearest to will: gives, should, won't, likes, an, really, down, blames,
# Nearest to arrives: future, here, house, there, car, prefers, UNK, give,
# Nearest to future: arrives, house, there, here, it, car, mary, book,
# Nearest to can: doesn't, should, his, really, week, prefers, is, give,
# Nearest to visit: finish, prefers, buy, new, likes, blames, loves, visits,
# Nearest to yesterday: bill, give, john's, is, in, for, blames, won't,
# Nearest to mary: what, who, car, future, china, week, book, sure,
# Nearest to for: bill, he, student, visits, give, i, book, yesterday,
# Nearest to loves: likes, blames, prefers, doesn't, won't, visits, is, tells,
# Nearest to book: in, give, for, not, bill, future, it, car,
# Nearest to should: will, gives, down, to, won't, an, really, doesn't,
# Nearest to that: his, who, will, what, to, should, down, woman,
# Nearest to john: who, here, week, what, he, that, really, brother,
# Nearest to a: new, tells, visit, for, visits, has, i, prefers,
# Nearest to what: car, mary, that, who, corn, john, he, somebody,
# Nearest to who: john, mary, that, here, car, not, what, future,
# Nearest to john's: in, give, yesterday, bill, doesn't, for, he, people,
# Nearest to go: finish, visits, there, buy, visit, corn, videotape, book,
# Nearest to in: give, john's, book, yesterday, vegtables, videotape, is, people,
# Nearest to one: videotape, girl, vegtables, UNK, teacher, people, and, it,
# Nearest to UNK: it, box, videotape, one, vegtables, book, arrives, future,
# Nearest to the: give, people, i, john's, new, book, bill, here,
# Nearest to buy: finish, visit, new, likes, to, go, videotape, corn,
# Nearest to to: should, woman, his, will, not, buy, is, that,
# Nearest to likes: loves, prefers, will, gives, won't, visit, blames, tells,
# Nearest to there: car, future, arrives, house, people, go, bill, not,
# Nearest to gives: will, should, won't, likes, down, an, doesn't, loves,
# Nearest to house: future, arrives, there, student, car, here, his, bill,
# Nearest to is: loves, yesterday, blames, prefers, tells, in, to, visit,
# Average loss at step 92000: 0.364519
# Average loss at step 94000: 0.362841
# Average loss at step 96000: 0.363998
# Average loss at step 98000: 0.363078
# Average loss at step 100000: 0.363144
# Nearest to car: what, there, future, house, mary, arrives, his, it,
# Nearest to will: gives, should, won't, likes, an, really, down, blames,
# Nearest to arrives: future, here, house, there, car, prefers, doesn't, UNK,
# Nearest to future: house, arrives, there, here, car, it, mary, box,
# Nearest to can: doesn't, should, his, really, week, prefers, is, give,
# Nearest to visit: finish, prefers, buy, new, likes, blames, loves, visits,
# Nearest to yesterday: give, bill, john's, is, in, blames, for, won't,
# Nearest to mary: what, who, car, future, china, book, week, sure,
# Nearest to for: bill, he, student, give, visits, i, book, yesterday,
# Nearest to loves: blames, likes, prefers, doesn't, won't, visits, is, tells,
# Nearest to book: give, in, for, not, bill, future, it, car,
# Nearest to should: gives, will, down, to, won't, an, really, doesn't,
# Nearest to that: his, who, what, will, down, should, to, woman,
# Nearest to john: who, here, week, what, he, that, somebody, really,
# Nearest to a: new, tells, visit, for, visits, i, has, student,
# Nearest to what: car, mary, that, who, corn, john, he, somebody,
# Nearest to who: john, mary, that, here, car, not, what, future,
# Nearest to john's: give, in, yesterday, bill, doesn't, for, people, he,
# Nearest to go: finish, visits, buy, there, visit, videotape, corn, book,
# Nearest to in: give, john's, book, yesterday, vegtables, videotape, is, box,
# Nearest to one: videotape, girl, vegtables, UNK, teacher, people, sell, it,
# Nearest to UNK: it, box, videotape, vegtables, one, book, future, arrives,
# Nearest to the: give, people, i, new, john's, book, bill, here,
# Nearest to buy: finish, visit, new, go, likes, to, videotape, corn,
# Nearest to to: should, woman, his, will, finish, is, not, buy,
# Nearest to likes: loves, prefers, will, gives, won't, visit, blames, doesn't,
# Nearest to there: car, future, arrives, house, people, go, bill, here,
# Nearest to gives: will, should, won't, down, likes, an, doesn't, really,
# Nearest to house: future, arrives, there, car, student, here, his, bill,
# Nearest to is: yesterday, loves, blames, prefers, tells, in, to, visit,

# %%
num_points = vocabulary_size-1

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
