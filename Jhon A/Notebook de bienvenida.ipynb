# %% [markdown]
# ## Agudelo

# %% [markdown]
# En estos notebooks vamos a correr una red neuronal para interpretar texto.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.


from __future__ import print_function
import collections
import math
import tensorflow as tf
import numpy as np
import os
import random
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# %matplotlib inline

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

# skip_window: int : How many words to consider left and right.
def generate_cbow_batch(batch_size, skip_window):
  global data_index
#   assert batch_size % num_skips == 0
#   assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, skip_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
#   buffer = []
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
  for i in range(batch_size):
    batch[i] = list(buffer)[:skip_window] + list(buffer)[skip_window+1:]
    labels[i] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels

# %%
batch,labels = generate_cbow_batch(128,1)

# %%
batch[:10]
# Out:
# array([[5234,   12],
#        [3081,    6],
#        [  12,  195],
#        [   6,    2],
#        [ 195, 3134],
#        [   2,   46],
#        [3134,   59],
#        [  46,  156],
#        [  59,  128],
#        [ 156,  742]])

# %%
labels[:10]
# Out:
# array([[3081],
#        [  12],
#        [   6],
#        [ 195],
#        [   2],
#        [3134],
#        [  46],
#        [  59],
#        [ 156],
#        [ 128]])

# %%
for i in range (np.random.randint(28) , np.random.randint(28)+100 ):
    print ('input: ({},{}) -- label:({})'.format(reverse_dictionary[batch[i,0]], reverse_dictionary[batch[i,1]],
                                                reverse_dictionary[labels[i][0]]))
# Out:
# input: (working,radicals) -- label:(class)
# input: (class,including) -- label:(radicals)
# input: (radicals,the) -- label:(including)
# input: (including,diggers) -- label:(the)
# input: (the,of) -- label:(diggers)
# input: (diggers,the) -- label:(of)
# input: (of,english) -- label:(the)
# input: (the,revolution) -- label:(english)
# input: (english,and) -- label:(revolution)
# input: (revolution,the) -- label:(and)
# input: (and,sans) -- label:(the)
# input: (the,UNK) -- label:(sans)
# input: (sans,of) -- label:(UNK)
# input: (UNK,the) -- label:(of)
# input: (of,french) -- label:(the)
# input: (the,revolution) -- label:(french)
# input: (french,whilst) -- label:(revolution)
# input: (revolution,the) -- label:(whilst)
# input: (whilst,term) -- label:(the)
# input: (the,is) -- label:(term)
# input: (term,still) -- label:(is)
# input: (is,used) -- label:(still)
# input: (still,in) -- label:(used)
# input: (used,a) -- label:(in)
# input: (in,pejorative) -- label:(a)
# input: (a,way) -- label:(pejorative)
# input: (pejorative,to) -- label:(way)
# input: (way,describe) -- label:(to)
# input: (to,any) -- label:(describe)
# input: (describe,act) -- label:(any)
# input: (any,that) -- label:(act)
# input: (act,used) -- label:(that)
# input: (that,violent) -- label:(used)
# input: (used,means) -- label:(violent)
# input: (violent,to) -- label:(means)
# input: (means,destroy) -- label:(to)
# input: (to,the) -- label:(destroy)
# input: (destroy,organization) -- label:(the)
# input: (the,of) -- label:(organization)
# input: (organization,society) -- label:(of)
# input: (of,it) -- label:(society)
# input: (society,has) -- label:(it)
# input: (it,also) -- label:(has)
# input: (has,been) -- label:(also)
# input: (also,taken) -- label:(been)
# input: (been,up) -- label:(taken)
# input: (taken,as) -- label:(up)
# input: (up,a) -- label:(as)
# input: (as,positive) -- label:(a)
# input: (a,label) -- label:(positive)
# input: (positive,by) -- label:(label)
# input: (label,self) -- label:(by)
# input: (by,defined) -- label:(self)
# input: (self,anarchists) -- label:(defined)
# input: (defined,the) -- label:(anarchists)
# input: (anarchists,word) -- label:(the)
# input: (the,anarchism) -- label:(word)
# input: (word,is) -- label:(anarchism)
# input: (anarchism,derived) -- label:(is)
# input: (is,from) -- label:(derived)
# input: (derived,the) -- label:(from)
# input: (from,greek) -- label:(the)
# input: (the,without) -- label:(greek)
# input: (greek,archons) -- label:(without)
# input: (without,ruler) -- label:(archons)
# input: (archons,chief) -- label:(ruler)
# input: (ruler,king) -- label:(chief)
# input: (chief,anarchism) -- label:(king)
# input: (king,as) -- label:(anarchism)
# input: (anarchism,a) -- label:(as)
# input: (as,political) -- label:(a)
# input: (a,philosophy) -- label:(political)
# input: (political,is) -- label:(philosophy)
# input: (philosophy,the) -- label:(is)
# input: (is,belief) -- label:(the)
# input: (the,that) -- label:(belief)
# input: (belief,rulers) -- label:(that)
# input: (that,are) -- label:(rulers)
# input: (rulers,unnecessary) -- label:(are)
# input: (are,and) -- label:(unnecessary)
# input: (unnecessary,should) -- label:(and)
# input: (and,be) -- label:(should)
# input: (should,abolished) -- label:(be)
# input: (be,although) -- label:(abolished)
# input: (abolished,there) -- label:(although)
# input: (although,are) -- label:(there)
# input: (there,differing) -- label:(are)
# input: (are,interpretations) -- label:(differing)
# input: (differing,of) -- label:(interpretations)
# input: (interpretations,what) -- label:(of)
# input: (of,this) -- label:(what)
# input: (what,means) -- label:(this)
# input: (this,anarchism) -- label:(means)
# input: (means,also) -- label:(anarchism)
# input: (anarchism,refers) -- label:(also)
# input: (also,to) -- label:(refers)
# input: (refers,related) -- label:(to)
# input: (to,social) -- label:(related)
# input: (related,movements) -- label:(social)
# input: (social,that) -- label:(movements)
# input: (movements,advocate) -- label:(that)

# %%
# CBOW model

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  # note the different input dimensions for the CBOW model
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # note the sum over the context embeddings for the CBOW model
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.reduce_sum(embed, 1)

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.692390
# Nearest to see: disband, metronome, operational, diversifying, baronet, archeologist, jan, ensemble,
# Nearest to d: recharge, aardvarks, bloomberg, clicks, mei, decentralized, extravagant, acyclic,
# Nearest to such: codes, nudes, counselling, mustafa, hopped, hawker, supported, presenters,
# Nearest to it: structure, bahia, shiv, accommodated, mephisto, syphilis, absurdum, civilisations,
# Nearest to time: dedicates, frigate, okeh, nippon, today, bastille, gatehouse, device,
# Nearest to may: eden, erika, inhumane, warn, columba, danforth, undefended, ene,
# Nearest to many: lafur, hashing, jsp, doren, heel, slide, tamers, rimfire,
# Nearest to some: eine, complicate, spectacular, incompetence, axum, enlisted, haider, spearhead,
# Nearest to into: mayotte, viewed, bra, bends, gnosis, sinti, katy, dominion,
# Nearest to b: covenant, payoffs, pavel, tarn, sdi, shepherds, papeete, interconnect,
# Nearest to over: characteristically, lumber, reinhardt, wields, vulgaris, transplants, jermaine, lott,
# Nearest to an: operatorname, barbarian, installed, facilitated, computers, scales, convention, darpa,
# Nearest to and: tiling, squarepants, pittsburgh, cafeteria, comically, unlocked, muds, insist,
# Nearest to these: dissection, suharto, roam, implements, kabir, ferruccio, exquisite, nurturing,
# Nearest to but: jabir, noirs, way, optionally, overruns, prostaglandins, isoroku, cytotoxic,
# Nearest to with: ed, rhymes, patrice, rodeo, daewoo, kabbalah, frequently, hippodrome,
# Average loss at step 2000: 4.091516
# Average loss at step 4000: 3.553198
# Average loss at step 6000: 3.379704
# Average loss at step 8000: 3.239171
# Average loss at step 10000: 3.176292
# Nearest to see: diversifying, poids, jan, investigation, theorizing, presiding, disband, but,
# Nearest to d: b, acyclic, dobbs, mei, turkestan, nsfnet, unresponsive, nsu,
# Nearest to such: well, vegetarian, known, atc, these, defined, hara, counselling,
# Nearest to it: he, this, she, there, they, necessitating, often, which,
# Nearest to time: abe, dedicates, today, nicene, thar, device, competitors, nippon,
# Nearest to may: can, would, will, could, cannot, should, must, might,
# Nearest to many: some, several, various, all, these, other, most, hashing,
# Nearest to some: many, all, these, other, lignite, identifies, newtonian, this,
# Nearest to into: from, coordination, with, by, after, eg, aba, floors,
# Nearest to b: d, covenant, luna, squaring, tarn, nora, chemist, sexuality,
# Nearest to over: wields, vulgaris, jermaine, nightingale, characteristically, fredrik, spoiled, aquarii,
# Nearest to an: corot, golfers, affective, flick, barbarian, dundas, endings, laertius,
# Nearest to and: or, stems, nis, comically, anatomical, fleece, stds, habitable,
# Nearest to these: some, hawkeye, many, such, exquisite, spinoff, southerly, accurately,
# Nearest to but: however, although, boroughs, warners, given, ansbach, tombalbaye, iic,
# Nearest to with: between, including, into, in, oligosaccharides, smashing, by, patrice,
# Average loss at step 12000: 3.197166
# Average loss at step 14000: 3.149925
# Average loss at step 16000: 3.172539
# Average loss at step 18000: 3.117877
# Average loss at step 20000: 2.987930
# Nearest to see: but, diversifying, astbury, brainwashing, agnosticism, transmembrane, homonyms, external,
# Nearest to d: b, acyclic, dobbs, mei, recharge, assured, stinging, dj,
# Nearest to such: these, known, well, many, defined, talladega, vegetarian, atc,
# Nearest to it: he, this, she, there, they, nutrients, span, fawlty,
# Nearest to time: year, abe, day, stephane, dedicates, way, centuries, rejoined,
# Nearest to may: can, would, will, could, cannot, should, must, might,
# Nearest to many: some, several, all, most, these, various, such, those,
# Nearest to some: many, these, several, all, any, this, identifies, eine,
# Nearest to into: from, coordination, domesday, gnosis, through, neptunian, eg, after,
# Nearest to b: d, squaring, covenant, lf, nora, luna, tarn, lala,
# Nearest to over: harvesting, wields, discordia, out, spoiled, through, skydiving, secures,
# Nearest to an: endings, barbarian, flick, affective, surinam, beuve, stretched, dundas,
# Nearest to and: or, but, while, bbb, rosenzweig, chests, unlocked, obiang,
# Nearest to these: some, such, hawkeye, many, several, certain, there, both,
# Nearest to but: however, and, although, until, see, where, woodlands, he,
# Nearest to with: between, including, gay, smashing, sore, coordination, endosymbiotic, wanderer,
# Average loss at step 22000: 3.069615
# Average loss at step 24000: 3.032769
# Average loss at step 26000: 3.000077
# Average loss at step 28000: 3.025039
# Average loss at step 30000: 3.001023
# Nearest to see: but, external, calculate, blacksmith, ions, hilly, chant, agnosticism,
# Nearest to d: b, acyclic, struggles, dr, summons, stylization, recharge, dobbs,
# Nearest to such: these, known, well, many, certain, defined, vegetarian, atc,
# Nearest to it: he, she, this, there, they, fawlty, still, what,
# Nearest to time: year, abe, thing, stephane, way, day, victories, marriage,
# Nearest to may: can, will, would, could, should, must, might, cannot,
# Nearest to many: some, several, various, these, such, both, most, certain,
# Nearest to some: many, several, these, any, certain, various, each, those,
# Nearest to into: from, through, mississippian, within, coordination, domesday, neptunian, sociological,
# Nearest to b: d, r, c, n, persona, minotaurs, atomists, reflectors,
# Nearest to over: through, harvesting, goodfellas, out, off, cma, secures, autoerotic,
# Nearest to an: flick, ashford, affective, surinam, corot, endings, flagellate, fernandez,
# Nearest to and: or, but, synoptic, cleef, like, misheard, including, defends,
# Nearest to these: many, such, some, hawkeye, several, both, those, certain,
# Nearest to but: however, and, although, moncton, abbreviating, which, see, pinto,
# Nearest to with: between, patrice, when, warranty, dagesh, sore, diogenes, flyer,
# Average loss at step 32000: 2.823887
# Average loss at step 34000: 2.952641
# Average loss at step 36000: 2.945365
# Average loss at step 38000: 2.944882
# Average loss at step 40000: 2.917184
# Nearest to see: includes, catalan, provides, external, disappointments, endless, include, memorable,
# Nearest to d: b, acyclic, sharkey, summons, f, dr, remarking, recharge,
# Nearest to such: these, well, known, like, many, atc, vegetarian, soon,
# Nearest to it: he, she, there, this, fawlty, they, transcribing, doubtful,
# Nearest to time: year, victories, stephane, centuries, thing, rejoined, marriage, abe,
# Nearest to may: can, will, would, could, should, must, might, cannot,
# Nearest to many: some, several, various, both, most, these, numerous, those,
# Nearest to some: many, several, various, certain, both, any, most, those,
# Nearest to into: through, from, within, across, coordination, domesday, sociological, under,
# Nearest to b: d, r, c, persona, acyclic, wiped, single, j,
# Nearest to over: cma, off, through, goodfellas, out, nightingale, secures, definitional,
# Nearest to an: flick, ashford, surinam, brutally, beuve, corot, golfers, dundas,
# Nearest to and: or, but, while, varese, including, puck, hemorrhagic, although,
# Nearest to these: such, several, those, hawkeye, both, many, various, which,
# Nearest to but: however, although, while, and, than, moncton, remarque, vms,
# Nearest to with: between, exonerated, when, patrice, dagesh, while, diogenes, sore,
# Average loss at step 42000: 2.946120
# Average loss at step 44000: 2.960757
# Average loss at step 46000: 2.906305
# Average loss at step 48000: 2.865905
# Average loss at step 50000: 2.848737
# Nearest to see: includes, external, ions, catalan, include, imbalances, remarque, but,
# Nearest to d: b, ignacio, dobbs, mep, emanuel, q, acyclic, nsu,
# Nearest to such: well, known, these, defined, certain, many, reflectance, viewed,
# Nearest to it: he, she, this, there, dysprosium, they, today, fawlty,
# Nearest to time: year, victories, grief, thing, period, marriage, centuries, histone,
# Nearest to may: can, could, would, will, should, must, might, cannot,
# Nearest to many: some, several, various, these, all, most, numerous, certain,
# Nearest to some: many, several, certain, any, these, most, various, all,
# Nearest to into: through, within, under, from, mississippian, across, neptunian, domesday,
# Nearest to b: d, luna, covenant, persona, acyclic, r, ignacio, angevin,
# Nearest to over: off, through, out, numbering, skydiving, goodfellas, harvesting, coercive,
# Nearest to an: flick, brutally, ashford, the, affective, stretched, corot, allosaurus,
# Nearest to and: or, but, american, while, meme, unlocked, faso, attendants,
# Nearest to these: several, many, some, those, various, both, such, hawkeye,
# Nearest to but: however, although, while, and, though, remarque, occur, do,
# Nearest to with: between, using, patrice, including, within, dagesh, manus, when,
# Average loss at step 52000: 2.882669
# Average loss at step 54000: 2.860433
# Average loss at step 56000: 2.859668
# Average loss at step 58000: 2.751349
# Average loss at step 60000: 2.830616
# Nearest to see: includes, include, but, refers, hilly, applies, external, list,
# Nearest to d: b, ignacio, l, dobbs, kw, nene, remarking, azul,
# Nearest to such: known, well, these, certain, many, including, atc, defined,
# Nearest to it: he, she, there, this, they, fawlty, dysprosium, itself,
# Nearest to time: thing, victories, period, controversy, year, way, eth, day,
# Nearest to may: can, could, should, would, must, might, will, cannot,
# Nearest to many: some, several, various, all, numerous, these, certain, few,
# Nearest to some: many, several, any, certain, these, all, various, each,
# Nearest to into: through, within, under, from, across, mississippian, around, coordination,
# Nearest to b: d, r, dobbs, q, persona, c, x, g,
# Nearest to over: within, through, between, skydiving, across, off, goodfellas, coercive,
# Nearest to an: flick, brutally, another, beuve, surinam, netware, golfers, junichiro,
# Nearest to and: or, but, although, however, while, comically, synoptic, hutcheson,
# Nearest to these: several, those, many, various, some, numerous, hawkeye, such,
# Nearest to but: however, although, and, though, see, which, remarque, than,
# Nearest to with: between, manus, sla, patrice, within, among, awm, atop,
# Average loss at step 62000: 2.828868
# Average loss at step 64000: 2.776264
# Average loss at step 66000: 2.757416
# Average loss at step 68000: 2.717210
# Average loss at step 70000: 2.788064
# Nearest to see: includes, external, include, provides, bledsoe, but, sis, oscars,
# Nearest to d: b, ignacio, emanuel, dj, sexuality, nene, nsu, dobbs,
# Nearest to such: known, well, defined, follows, viewed, many, regarded, these,
# Nearest to it: she, he, there, they, this, fawlty, dysprosium, soon,
# Nearest to time: period, jurisdiction, victories, day, days, thing, year, stephane,
# Nearest to may: should, could, must, can, might, will, cannot, would,
# Nearest to many: some, several, various, numerous, all, those, certain, few,
# Nearest to some: many, several, certain, various, any, these, numerous, most,
# Nearest to into: through, within, from, chanson, across, under, primed, mississippian,
# Nearest to b: d, crioulo, persona, tuck, luna, vestiges, swedish, isbns,
# Nearest to over: skydiving, within, off, through, goodfellas, coercive, dhole, proxima,
# Nearest to an: flick, another, ashford, surinam, famously, golfers, affective, ecuadorean,
# Nearest to and: or, but, although, including, contraindicated, contending, micrometers, unlocked,
# Nearest to these: those, several, various, some, hawkeye, numerous, many, all,
# Nearest to but: however, although, though, and, remarque, flanagan, see, until,
# Nearest to with: between, within, whereby, kerouac, under, against, atop, patrice,
# Average loss at step 72000: 2.794689
# Average loss at step 74000: 2.647984
# Average loss at step 76000: 2.796531
# Average loss at step 78000: 2.822423
# Average loss at step 80000: 2.778971
# Nearest to see: include, external, includes, hilly, bledsoe, according, refers, called,
# Nearest to d: b, dolce, nsu, recharge, flaubert, decentralized, l, ed,
# Nearest to such: well, known, certain, viewed, follows, serve, many, opposed,
# Nearest to it: he, she, there, this, itself, they, we, fawlty,
# Nearest to time: period, victories, year, thing, jurisdiction, degree, histone, day,
# Nearest to may: could, might, can, should, would, must, cannot, will,
# Nearest to many: several, some, numerous, various, all, certain, those, both,
# Nearest to some: many, several, certain, any, these, various, most, multiple,
# Nearest to into: through, within, from, across, mississippian, down, chanson, around,
# Nearest to b: d, q, v, c, h, p, r, persona,
# Nearest to over: off, skydiving, through, around, about, proxima, within, punishing,
# Nearest to an: beuve, flick, ashford, golfers, pekah, famously, affective, dar,
# Nearest to and: or, but, including, although, of, puck, etc, however,
# Nearest to these: those, some, several, many, hawkeye, certain, they, various,
# Nearest to but: however, although, though, and, which, citing, compartments, volvo,
# Nearest to with: between, patrice, using, endosymbiotic, sore, kerouac, whereby, abolitionists,
# Average loss at step 82000: 2.663774
# Average loss at step 84000: 2.768804
# Average loss at step 86000: 2.734053
# Average loss at step 88000: 2.749815
# Average loss at step 90000: 2.730302
# Nearest to see: include, includes, external, but, list, bledsoe, known, references,
# Nearest to d: b, l, nsu, decentralized, recharge, sharkey, r, c,
# Nearest to such: well, known, these, viewed, serve, many, follows, heavenly,
# Nearest to it: she, he, there, this, they, fawlty, itself, tatian,
# Nearest to time: jurisdiction, victories, year, period, day, month, stephane, controversy,
# Nearest to may: must, could, can, should, would, might, cannot, will,
# Nearest to many: several, some, numerous, various, certain, all, few, most,
# Nearest to some: many, several, certain, most, various, any, both, all,
# Nearest to into: through, within, chanson, from, across, mississippian, under, primed,
# Nearest to b: d, c, l, q, r, k, j, f,
# Nearest to over: off, skydiving, through, around, secures, clos, about, dhole,
# Nearest to an: golfers, flick, surinam, ashford, dundas, peoria, beuve, brutally,
# Nearest to and: or, but, including, although, digby, via, tiling, though,
# Nearest to these: those, several, certain, such, many, hawkeye, various, multiple,
# Nearest to but: however, although, though, and, which, see, than, reigning,
# Nearest to with: between, patrice, within, autocratic, including, biggs, using, atop,
# Average loss at step 92000: 2.672217
# Average loss at step 94000: 2.724718
# Average loss at step 96000: 2.695456
# Average loss at step 98000: 2.360336
# Average loss at step 100000: 2.399934
# Nearest to see: includes, include, external, references, refers, list, known, bledsoe,
# Nearest to d: b, ignacio, educating, horthy, nsu, mei, multitasking, squaring,
# Nearest to such: well, known, these, many, serve, follows, served, heavenly,
# Nearest to it: he, she, there, this, fawlty, they, itself, probably,
# Nearest to time: period, reign, victories, day, stephane, month, ruler, thing,
# Nearest to may: could, must, would, should, can, might, cannot, will,
# Nearest to many: some, several, numerous, various, multiple, certain, few, all,
# Nearest to some: many, several, certain, any, numerous, various, this, multiple,
# Nearest to into: through, under, across, chanson, within, back, down, mississippian,
# Nearest to b: d, swedish, instituto, tuck, luna, sup, crioulo, olden,
# Nearest to over: off, around, skydiving, handedly, hedley, about, punishing, dhole,
# Nearest to an: flick, ashford, peoria, golfers, pekah, surinam, beuve, dar,
# Nearest to and: or, but, though, including, attendants, angelina, unipolar, contraindicated,
# Nearest to these: those, several, hawkeye, such, certain, they, there, multiple,
# Nearest to but: however, although, though, and, while, until, unfortunately, reigning,
# Nearest to with: between, by, makes, whereby, patrice, abolitionists, jahan, endosymbiotic,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
