# %%
import tensorflow as tf
import collections
import numpy as np
import pandas as pd
import random
import math
from sklearn.manifold import TSNE
from matplotlib import pylab

# %%
def create_dataset(trainFileName, TestFileName):
    train_data = pd.read_csv(trainFileName,delimiter=";")
    test_data  = pd.read_csv(testFileName,delimiter=";")
    sentences_train = [sentence[:len(sentence) -1 ] for sentence in train_data.translation]
    sentences_test = [sentence[:len(sentence) -1 ] for sentence in train_data.translation]
    sentences = sentences_train + sentences_test
    words = []
    for sentence in sentences:
        sentence = sentence.split()
        for  i in range (len(sentence)):
            word = sentence[i]
            word = str.lower(word)
            word = word.rstrip(",")
            word = word.rstrip(".")
            word = word.rstrip("?")
            words.append(word)
    del train_data
    del sentences
    del sentences_test
    del sentences_train
    return words

# %%
trainFileName = 'train.sentences.pronunciations.multi.translations.csv'
testFileName = "test.sentences.multi.translations.csv" 
words = create_dataset(trainFileName, testFileName)
vocabulary_size = len(collections.Counter(words).most_common())
print("El vocabulario de este dataset consiste en un total de {} palabras diferentes".format(vocabulary_size))
display(collections.Counter(words).most_common())
# Out:
# El vocabulario de este dataset consiste en un total de 148 palabras diferentes
# [('john', 200),
#  ('the', 156),
#  ('mary', 74),
#  ('a', 42),
#  ('in', 40),
#  ('is', 40),
#  ('to', 36),
#  ('book', 36),
#  ('who', 36),
#  ('future', 34),
#  ('car', 32),
#  ('go', 30),
#  ('loves', 28),
#  ('there', 26),
#  ('that', 26),
#  ('buy', 26),
#  ('arrives', 26),
#  ('will', 24),
#  ('visit', 24),
#  ("john's", 24),
#  ('gives', 24),
#  ('likes', 22),
#  ('yesterday', 20),
#  ('house', 20),
#  ('what', 20),
#  ('one', 20),
#  ('for', 18),
#  ('should', 18),
#  ('can', 16),
#  ("won't", 14),
#  ('visits', 14),
#  ('new', 14),
#  ('woman', 14),
#  ('bill', 14),
#  ('sure', 12),
#  ('vegtables', 12),
#  ('he', 12),
#  ('i', 10),
#  ('corn', 10),
#  ('prefers', 10),
#  ('has', 10),
#  ('buys', 10),
#  ('an', 10),
#  ('apple', 10),
#  ('girl', 10),
#  ('box', 10),
#  ('blames', 8),
#  ('people', 8),
#  ('this', 8),
#  ('and', 8),
#  ('not', 8),
#  ('here', 8),
#  ('breaks', 8),
#  ('down', 8),
#  ('sue', 8),
#  ('blue', 8),
#  ('bought', 8),
#  ('really', 8),
#  ('give', 8),
#  ('teacher', 8),
#  ('his', 6),
#  ('visited', 6),
#  ('eat', 6),
#  ('leaves', 6),
#  ('tells', 6),
#  ('over', 6),
#  ("doesn't", 6),
#  ('chocolate', 6),
#  ('some', 6),
#  ("frank's", 6),
#  ('student', 6),
#  ('videotape', 6),
#  ('it', 6),
#  ('told', 6),
#  ('throws', 6),
#  ('on', 6),
#  ('fish', 4),
#  ('but', 4),
#  ('eats', 4),
#  ('chicken', 4),
#  ('china', 4),
#  ('prefer', 4),
#  ('broccoli', 4),
#  ('knows', 4),
#  ('thinks', 4),
#  ('him', 4),
#  ('decides', 4),
#  ('movie', 4),
#  ('wants', 4),
#  ('sell', 4),
#  ('week', 4),
#  ('york', 4),
#  ('be', 4),
#  ('finish', 4),
#  ('reading', 4),
#  ('somebody', 4),
#  ('brother', 4),
#  ('man', 4),
#  ('coat', 4),
#  ('which', 4),
#  ('someones', 4),
#  ('stolen', 4),
#  ('mother', 4),
#  ('whom', 4),
#  ('says', 4),
#  ('herself', 4),
#  ('jana', 4),
#  ('toys', 4),
#  ('all', 4),
#  ('boys', 4),
#  ('boy', 4),
#  ('writes', 2),
#  ('homework', 2),
#  ('party', 2),
#  ('fred', 2),
#  ('being', 2),
#  ('hit', 2),
#  ('know', 2),
#  ('lived', 2),
#  ('chicago', 2),
#  ('next', 2),
#  ('last', 2),
#  ('ann', 2),
#  ('like', 2),
#  ('find', 2),
#  ('owns', 2),
#  ('searches', 2),
#  ('owner', 2),
#  ('of', 2),
#  ('leg', 2),
#  ('friend', 2),
#  ('candy', 2),
#  ('old', 2),
#  ('was', 2),
#  ('sold', 2),
#  ('reads', 2),
#  ('borrows', 2),
#  ('someone', 2),
#  ('potatoes', 2),
#  ('name', 2),
#  ('frank', 2),
#  ('shot', 2),
#  ('she', 2),
#  ('many', 2),
#  ('get', 2),
#  ('puts', 2),
#  ('aside', 2),
#  ('arrive', 2)]

# %%
def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1 ))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)

# %%
data_index = 0
batch_size = 32
# skip_window: int : How many words to consider left and right.
def generate_cbow_batch(batch_size, skip_window):
  global data_index
#   assert batch_size % num_skips == 0
#   assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, skip_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
#   buffer = []
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
  for i in range(batch_size):
    batch[i] = list(buffer)[:skip_window] + list(buffer)[skip_window+1:]
    labels[i] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels
batch,labels = generate_cbow_batch(10,1)

# %%
for i in range (0 , 10 ):
    print ('input: ({0},{1}) -- label:({2}) -- sentence: {0} {2} {1}'.format(reverse_dictionary[batch[i,0]],
                                                                               reverse_dictionary[batch[i,1]],
                                                                               reverse_dictionary[labels[i][0]]))
# Out:
# input: (john,his) -- label:(writes) -- sentence: john writes his
# input: (writes,homework) -- label:(his) -- sentence: writes his homework
# input: (his,i) -- label:(homework) -- sentence: his homework i
# input: (homework,visited) -- label:(i) -- sentence: homework i visited
# input: (i,john) -- label:(visited) -- sentence: i visited john
# input: (visited,there) -- label:(john) -- sentence: visited john there
# input: (john,yesterday) -- label:(there) -- sentence: john there yesterday
# input: (there,i) -- label:(yesterday) -- sentence: there yesterday i
# input: (yesterday,visited) -- label:(i) -- sentence: yesterday i visited
# input: (i,john) -- label:(visited) -- sentence: i visited john

# %%
# CBOW model
embedding_size = 32 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 30 # Random set of words to evaluate similarity on.
valid_window = 30 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 30 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  # note the different input dimensions for the CBOW model
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # note the sum over the context embeddings for the CBOW model
  #Búsqueda de los parámetros dados en el training batch
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  #Realiza una suma a través de las filas
  embed = tf.reduce_sum(embed, 1)

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 4.537932
# Nearest to who: broccoli, breaks, was, party, last, boys, leaves, she,
# Nearest to in: chocolate, leaves, borrows, leg, it, UNK, fish, broccoli,
# Nearest to house: blames, box, many, next, likes, loves, here, prefer,
# Nearest to that: borrows, frank, bought, he, in, candy, new, lived,
# Nearest to one: breaks, there, hit, ann, bill, party, someones, finish,
# Nearest to to: the, yesterday, car, student, really, apple, tells, girl,
# Nearest to car: student, find, to, movie, teacher, reading, old, friend,
# Nearest to the: to, throws, owner, being, should, find, frank, and,
# Nearest to mary: buys, frank, new, not, fish, puts, someone, will,
# Nearest to a: on, future, will, last, wants, finish, puts, potatoes,
# Nearest to UNK: what, homework, people, visits, an, boy, leg, it,
# Nearest to is: sure, john's, aside, box, corn, really, visits, likes,
# Nearest to for: john's, girl, knows, week, says, but, jana, visits,
# Nearest to there: finish, owner, apple, told, one, his, next, toys,
# Nearest to gives: give, searches, week, arrives, he, visited, somebody, buys,
# Nearest to john's: corn, for, is, find, here, woman, like, girl,
# Nearest to will: down, a, owns, student, potatoes, not, find, knows,
# Nearest to john: jana, throws, woman, arrives, she, i, last, visit,
# Nearest to should: and, find, i, the, decides, aside, like, ann,
# Nearest to likes: prefer, house, corn, here, is, over, writes, herself,
# Nearest to loves: won't, house, many, chicago, on, being, tells, next,
# Nearest to visit: jana, chicken, owner, told, john, man, she, sell,
# Nearest to go: i, stolen, next, told, a, coat, to, friend,
# Nearest to what: UNK, be, buys, over, owns, someones, chicago, buy,
# Nearest to buy: teacher, really, over, it, owns, what, vegtables, bill,
# Nearest to future: a, chicken, knows, old, student, whom, teacher, book,
# Nearest to book: owns, hit, over, future, finish, give, really, last,
# Nearest to arrives: chocolate, he, gives, homework, john, frank, sue, has,
# Nearest to yesterday: sure, to, was, breaks, girl, tells, all, many,
# Nearest to can: hit, breaks, was, sure, has, prefers, homework, john,
# Average loss at step 2000: 0.406894
# Average loss at step 4000: 0.229110
# Average loss at step 6000: 0.209804
# Average loss at step 8000: 0.196991
# Average loss at step 10000: 0.187847
# Nearest to who: whom, homework, she, him, mary, brother, mother, that,
# Nearest to in: give, aside, he, john, woman, of, herself, leaves,
# Nearest to house: chicago, movie, party, writes, blames, box, tells, there,
# Nearest to that: coat, blames, who, can, to, buys, borrows, york,
# Nearest to one: boy, UNK, vegtables, old, owner, ann, bill, someones,
# Nearest to to: is, frank's, has, should, aside, student, says, can,
# Nearest to car: coat, there, woman, movie, future, party, boy, should,
# Nearest to the: china, chicago, some, told, which, a, visit, many,
# Nearest to mary: stolen, frank, who, and, party, leg, sue, book,
# Nearest to a: old, some, finish, not, down, was, the, which,
# Nearest to UNK: vegtables, one, homework, boys, leg, for, brother, go,
# Nearest to is: aside, many, loves, to, visit, tells, likes, herself,
# Nearest to for: vegtables, knows, UNK, being, owner, one, homework, visit,
# Nearest to there: party, really, bill, car, over, future, bought, house,
# Nearest to gives: searches, leaves, box, shot, writes, thinks, buys, visited,
# Nearest to john's: name, all, last, aside, doesn't, knows, in, frank's,
# Nearest to will: should, won't, blames, doesn't, tells, loves, has, visits,
# Nearest to john: in, ann, sue, fish, teacher, last, one, someones,
# Nearest to should: can, will, likes, prefers, writes, bought, gives, really,
# Nearest to likes: prefers, should, decides, writes, won't, wants, gives, searches,
# Nearest to loves: tells, blames, is, won't, visits, wants, will, writes,
# Nearest to visit: buy, knows, loves, told, yesterday, throws, is, vegtables,
# Nearest to go: buy, UNK, know, book, finish, visit, york, told,
# Nearest to what: shot, chocolate, throws, frank, stolen, him, down, lived,
# Nearest to buy: visit, go, not, visits, finish, party, many, know,
# Nearest to future: boy, old, writes, people, over, box, on, party,
# Nearest to book: videotape, people, boy, sell, man, go, box, of,
# Nearest to arrives: writes, decides, lived, find, leaves, loves, sure, ann,
# Nearest to yesterday: herself, candy, visit, tells, aside, sure, is, leaves,
# Nearest to can: should, will, really, being, won't, to, not, week,
# Average loss at step 12000: 0.186968
# Average loss at step 14000: 0.187112
# Average loss at step 16000: 0.178922
# Average loss at step 18000: 0.175808
# Average loss at step 20000: 0.172116
# Nearest to who: whom, homework, she, mary, him, brother, mother, that,
# Nearest to in: give, aside, john, he, of, leaves, sure, john's,
# Nearest to house: party, movie, chicago, writes, box, there, blames, tells,
# Nearest to that: blames, coat, whom, who, can, what, his, to,
# Nearest to one: UNK, boy, vegtables, owner, for, someones, ann, bill,
# Nearest to to: frank's, should, is, can, has, aside, really, student,
# Nearest to car: coat, there, woman, movie, party, boy, future, leaves,
# Nearest to the: china, chicago, some, told, a, many, go, visit,
# Nearest to mary: stolen, frank, who, this, leg, party, and, sue,
# Nearest to a: old, some, down, finish, not, the, was, next,
# Nearest to UNK: vegtables, one, for, homework, boys, brother, go, leg,
# Nearest to is: aside, loves, many, visit, likes, tells, to, frank's,
# Nearest to for: vegtables, UNK, knows, owner, being, one, homework, visit,
# Nearest to there: party, really, car, future, over, chicago, bought, house,
# Nearest to gives: searches, writes, leaves, box, shot, thinks, buys, visited,
# Nearest to john's: name, frank's, all, knows, last, in, which, aside,
# Nearest to will: should, won't, blames, doesn't, tells, visits, loves, prefers,
# Nearest to john: in, ann, bill, fish, one, sue, someones, teacher,
# Nearest to should: can, will, likes, prefers, bought, gives, writes, to,
# Nearest to likes: prefers, should, decides, wants, gives, tells, writes, box,
# Nearest to loves: blames, tells, is, won't, wants, visits, reads, visit,
# Nearest to visit: yesterday, loves, knows, is, finish, told, buy, throws,
# Nearest to go: buy, book, know, UNK, chocolate, finish, vegtables, get,
# Nearest to what: shot, chocolate, stolen, throws, lived, frank, him, reads,
# Nearest to buy: not, visits, visit, go, finish, party, movie, many,
# Nearest to future: boy, old, people, writes, over, on, party, there,
# Nearest to book: videotape, people, sell, man, boy, go, candy, woman,
# Nearest to arrives: writes, leaves, lived, decides, reads, won't, sure, gives,
# Nearest to yesterday: herself, visit, candy, tells, sure, is, aside, buys,
# Nearest to can: should, will, really, to, being, not, gives, week,
# Average loss at step 22000: 0.170845
# Average loss at step 24000: 0.173517
# Average loss at step 26000: 0.167814
# Average loss at step 28000: 0.165240
# Average loss at step 30000: 0.163677
# Nearest to who: whom, him, homework, she, mary, brother, mother, toys,
# Nearest to in: give, john, aside, he, john's, of, leaves, sure,
# Nearest to house: party, movie, chicago, writes, there, box, loves, likes,
# Nearest to that: to, blames, what, whom, coat, can, broccoli, eats,
# Nearest to one: boy, UNK, vegtables, owner, for, someones, videotape, bill,
# Nearest to to: is, should, frank's, can, aside, has, that, really,
# Nearest to car: coat, there, woman, movie, boy, leaves, party, york,
# Nearest to the: china, chicago, some, told, which, a, blue, many,
# Nearest to mary: stolen, frank, who, leg, and, this, eats, party,
# Nearest to a: old, some, down, was, finish, not, the, next,
# Nearest to UNK: vegtables, for, one, homework, brother, boys, go, be,
# Nearest to is: loves, aside, many, visit, likes, to, tells, yesterday,
# Nearest to for: vegtables, knows, UNK, owner, being, one, homework, visit,
# Nearest to there: party, really, future, car, house, over, bill, chicago,
# Nearest to gives: searches, leaves, box, shot, writes, thinks, buys, visited,
# Nearest to john's: name, frank's, in, all, knows, last, aside, which,
# Nearest to will: should, blames, won't, tells, doesn't, visits, loves, prefers,
# Nearest to john: in, ann, one, someones, bill, fish, sue, teacher,
# Nearest to should: can, likes, will, prefers, bought, gives, writes, to,
# Nearest to likes: should, prefers, decides, wants, tells, writes, gives, visits,
# Nearest to loves: blames, is, tells, won't, wants, reads, visits, will,
# Nearest to visit: yesterday, buy, loves, is, knows, finish, throws, blames,
# Nearest to go: know, book, buy, chocolate, UNK, get, vegtables, finish,
# Nearest to what: chocolate, shot, stolen, throws, lived, frank, him, down,
# Nearest to buy: visit, visits, go, not, finish, party, many, loves,
# Nearest to future: boy, old, people, writes, over, on, party, there,
# Nearest to book: videotape, people, sell, boy, man, go, candy, woman,
# Nearest to arrives: writes, leaves, find, lived, hit, decides, reads, loves,
# Nearest to yesterday: visit, herself, candy, is, tells, aside, sure, loves,
# Nearest to can: should, will, to, really, being, teacher, not, won't,
# Average loss at step 32000: 0.168043
# Average loss at step 34000: 0.167128
# Average loss at step 36000: 0.161619
# Average loss at step 38000: 0.163921
# Average loss at step 40000: 0.163710
# Nearest to who: whom, homework, him, she, brother, mary, mother, john,
# Nearest to in: give, aside, john, he, john's, of, woman, car,
# Nearest to house: party, movie, chicago, writes, there, box, loves, corn,
# Nearest to that: blames, what, whom, to, broccoli, coat, can, eats,
# Nearest to one: boy, UNK, owner, vegtables, for, videotape, ann, bill,
# Nearest to to: should, is, frank's, can, aside, has, really, says,
# Nearest to car: coat, there, movie, woman, party, boy, leaves, future,
# Nearest to the: china, chicago, some, told, which, many, blue, a,
# Nearest to mary: stolen, frank, leg, who, this, party, eats, and,
# Nearest to a: old, down, some, was, not, finish, the, mother,
# Nearest to UNK: vegtables, one, for, homework, brother, boys, go, be,
# Nearest to is: aside, loves, many, visit, likes, yesterday, to, tells,
# Nearest to for: vegtables, owner, knows, UNK, one, being, homework, visit,
# Nearest to there: party, car, really, future, house, over, chicago, bill,
# Nearest to gives: searches, box, leaves, shot, buys, thinks, writes, visited,
# Nearest to john's: name, frank's, in, all, knows, aside, last, for,
# Nearest to will: should, won't, blames, tells, doesn't, prefers, visits, loves,
# Nearest to john: in, ann, one, someones, fish, teacher, somebody, bill,
# Nearest to should: can, likes, will, prefers, bought, gives, to, writes,
# Nearest to likes: prefers, should, decides, wants, tells, gives, writes, not,
# Nearest to loves: blames, is, tells, won't, wants, reads, writes, visits,
# Nearest to visit: yesterday, is, buy, loves, knows, finish, blames, prefer,
# Nearest to go: buy, know, book, chocolate, UNK, get, vegtables, finish,
# Nearest to what: stolen, chocolate, shot, lived, throws, frank, him, down,
# Nearest to buy: visit, not, visits, go, party, finish, many, loves,
# Nearest to future: boy, old, people, on, writes, over, party, there,
# Nearest to book: videotape, people, sell, man, boy, go, candy, woman,
# Nearest to arrives: writes, reads, decides, find, leaves, hit, lived, shot,
# Nearest to yesterday: visit, herself, candy, is, tells, sure, aside, loves,
# Nearest to can: should, will, to, really, being, teacher, finish, not,
# Average loss at step 42000: 0.163992
# Average loss at step 44000: 0.160307
# Average loss at step 46000: 0.160991
# Average loss at step 48000: 0.159511
# Average loss at step 50000: 0.162310
# Nearest to who: whom, homework, him, brother, she, mother, mary, toys,
# Nearest to in: give, aside, john, he, john's, of, car, sure,
# Nearest to house: party, movie, chicago, writes, box, there, loves, corn,
# Nearest to that: what, blames, whom, to, broccoli, eats, can, coat,
# Nearest to one: boy, UNK, owner, for, vegtables, videotape, someones, ann,
# Nearest to to: should, is, frank's, can, aside, has, whom, really,
# Nearest to car: coat, there, woman, movie, boy, leaves, party, york,
# Nearest to the: china, chicago, some, told, a, blue, down, many,
# Nearest to mary: stolen, frank, leg, this, party, eats, and, who,
# Nearest to a: some, old, down, was, not, the, finish, visit,
# Nearest to UNK: vegtables, one, for, homework, brother, boys, go, be,
# Nearest to is: aside, loves, many, visit, yesterday, to, tells, likes,
# Nearest to for: vegtables, owner, UNK, knows, one, homework, being, visit,
# Nearest to there: party, really, car, future, house, over, chicago, bill,
# Nearest to gives: searches, box, shot, leaves, writes, buys, thinks, visited,
# Nearest to john's: name, frank's, in, all, knows, which, last, for,
# Nearest to will: should, won't, blames, tells, doesn't, prefers, has, visits,
# Nearest to john: in, ann, someones, one, bill, somebody, fish, teacher,
# Nearest to should: can, likes, will, prefers, bought, gives, to, writes,
# Nearest to likes: prefers, should, decides, wants, gives, tells, writes, not,
# Nearest to loves: blames, tells, won't, is, wants, reads, visits, writes,
# Nearest to visit: yesterday, is, loves, knows, finish, buy, blames, herself,
# Nearest to go: book, know, chocolate, get, UNK, buy, vegtables, finish,
# Nearest to what: stolen, chocolate, shot, lived, frank, throws, him, down,
# Nearest to buy: not, visits, visit, party, finish, many, go, loves,
# Nearest to future: boy, old, people, on, writes, party, over, there,
# Nearest to book: videotape, people, sell, man, boy, go, candy, woman,
# Nearest to arrives: writes, reads, leaves, hit, decides, shot, find, loves,
# Nearest to yesterday: visit, herself, is, candy, tells, aside, sure, loves,
# Nearest to can: should, will, to, really, teacher, being, finish, not,
# Average loss at step 52000: 0.159396
# Average loss at step 54000: 0.158689
# Average loss at step 56000: 0.161375
# Average loss at step 58000: 0.160457
# Average loss at step 60000: 0.159962
# Nearest to who: whom, homework, him, mary, she, brother, mother, john,
# Nearest to in: give, john, aside, he, john's, of, car, ann,
# Nearest to house: party, movie, chicago, writes, there, box, loves, sure,
# Nearest to that: blames, to, whom, what, broccoli, eats, coat, can,
# Nearest to one: boy, UNK, owner, for, vegtables, john, ann, videotape,
# Nearest to to: should, is, can, frank's, has, aside, whom, that,
# Nearest to car: coat, there, movie, woman, boy, party, leaves, york,
# Nearest to the: china, chicago, some, told, down, here, a, decides,
# Nearest to mary: stolen, who, frank, leg, eats, this, party, fred,
# Nearest to a: down, old, some, was, not, the, mother, finish,
# Nearest to UNK: vegtables, for, one, homework, brother, boys, go, be,
# Nearest to is: loves, aside, visit, many, yesterday, likes, to, tells,
# Nearest to for: vegtables, owner, UNK, knows, one, being, homework, visit,
# Nearest to there: party, really, car, house, future, bill, over, chicago,
# Nearest to gives: searches, box, shot, leaves, writes, buys, thinks, doesn't,
# Nearest to john's: name, frank's, in, all, knows, which, last, for,
# Nearest to will: should, won't, blames, tells, doesn't, visits, gives, prefers,
# Nearest to john: in, one, ann, someones, somebody, fish, bill, sue,
# Nearest to should: can, likes, will, prefers, bought, to, gives, writes,
# Nearest to likes: prefers, should, decides, wants, gives, tells, visits, writes,
# Nearest to loves: blames, is, tells, reads, wants, won't, visits, writes,
# Nearest to visit: yesterday, is, loves, knows, finish, blames, herself, buy,
# Nearest to go: book, know, get, chocolate, UNK, vegtables, buy, finish,
# Nearest to what: chocolate, stolen, lived, shot, throws, frank, him, china,
# Nearest to buy: not, visits, party, many, visit, finish, go, blames,
# Nearest to future: old, boy, people, on, party, over, writes, leg,
# Nearest to book: videotape, people, sell, man, go, boy, candy, woman,
# Nearest to arrives: writes, reads, hit, leaves, loves, won't, decides, shot,
# Nearest to yesterday: visit, herself, is, candy, tells, sure, aside, blames,
# Nearest to can: should, to, will, really, teacher, being, finish, not,
# Average loss at step 62000: 0.157818
# Average loss at step 64000: 0.155731
# Average loss at step 66000: 0.157934
# Average loss at step 68000: 0.156333
# Average loss at step 70000: 0.158553
# Nearest to who: whom, homework, him, brother, she, mary, mother, toys,
# Nearest to in: give, aside, he, john, john's, of, ann, car,
# Nearest to house: party, movie, chicago, writes, there, box, loves, corn,
# Nearest to that: what, blames, whom, to, broccoli, eats, can, writes,
# Nearest to one: boy, UNK, owner, for, vegtables, john, videotape, ann,
# Nearest to to: should, can, is, frank's, aside, whom, really, has,
# Nearest to car: coat, there, movie, party, boy, woman, leaves, york,
# Nearest to the: china, chicago, some, told, down, many, blue, a,
# Nearest to mary: stolen, leg, frank, this, who, eats, party, fred,
# Nearest to a: down, old, some, not, was, the, mother, finish,
# Nearest to UNK: vegtables, one, for, homework, brother, boys, go, be,
# Nearest to is: aside, loves, many, visit, yesterday, likes, to, tells,
# Nearest to for: vegtables, owner, UNK, one, knows, homework, being, visit,
# Nearest to there: party, really, car, house, future, over, bill, chicago,
# Nearest to gives: searches, box, shot, writes, leaves, buys, doesn't, thinks,
# Nearest to john's: name, frank's, in, all, which, knows, for, last,
# Nearest to will: should, won't, blames, tells, prefers, gives, doesn't, visits,
# Nearest to john: one, ann, in, someones, somebody, fish, bill, teacher,
# Nearest to should: can, likes, will, prefers, bought, gives, to, writes,
# Nearest to likes: should, prefers, decides, wants, gives, tells, not, writes,
# Nearest to loves: blames, tells, is, won't, wants, reads, writes, visits,
# Nearest to visit: yesterday, is, finish, knows, loves, buy, herself, prefer,
# Nearest to go: book, get, know, chocolate, buy, UNK, vegtables, hit,
# Nearest to what: chocolate, stolen, lived, shot, throws, him, frank, china,
# Nearest to buy: not, visit, visits, party, go, finish, many, loves,
# Nearest to future: old, boy, people, on, party, over, writes, there,
# Nearest to book: videotape, people, sell, go, man, boy, candy, chicken,
# Nearest to arrives: writes, reads, hit, leaves, won't, shot, loves, decides,
# Nearest to yesterday: visit, herself, is, candy, tells, sure, aside, loves,
# Nearest to can: should, to, will, really, teacher, being, finish, not,
# Average loss at step 72000: 0.157583
# Average loss at step 74000: 0.158340
# Average loss at step 76000: 0.153153
# Average loss at step 78000: 0.153434
# Average loss at step 80000: 0.153203
# Nearest to who: whom, him, homework, brother, she, mary, mother, eats,
# Nearest to in: give, john's, he, aside, john, of, car, ann,
# Nearest to house: party, movie, chicago, writes, there, box, loves, sure,
# Nearest to that: to, what, whom, blames, broccoli, eats, writes, can,
# Nearest to one: boy, UNK, for, owner, vegtables, ann, videotape, john,
# Nearest to to: should, is, can, frank's, whom, aside, that, has,
# Nearest to car: coat, there, movie, party, boy, leaves, woman, york,
# Nearest to the: china, some, chicago, down, told, many, here, a,
# Nearest to mary: stolen, frank, leg, who, this, fred, eats, was,
# Nearest to a: down, old, some, was, not, the, mother, visit,
# Nearest to UNK: vegtables, one, for, homework, brother, boys, go, last,
# Nearest to is: loves, aside, many, visit, yesterday, to, likes, tells,
# Nearest to for: vegtables, owner, one, UNK, knows, homework, being, reading,
# Nearest to there: party, really, car, future, house, over, chicago, bought,
# Nearest to gives: searches, box, shot, leaves, writes, doesn't, reads, buys,
# Nearest to john's: name, in, frank's, which, all, knows, for, fish,
# Nearest to will: won't, should, blames, tells, prefers, doesn't, gives, visits,
# Nearest to john: in, one, someones, ann, somebody, bill, fish, sue,
# Nearest to should: can, likes, will, prefers, bought, to, gives, writes,
# Nearest to likes: prefers, should, decides, gives, wants, not, writes, tells,
# Nearest to loves: blames, is, tells, won't, wants, reads, visits, writes,
# Nearest to visit: yesterday, is, loves, buy, knows, finish, herself, prefer,
# Nearest to go: book, get, chocolate, know, buy, UNK, vegtables, hit,
# Nearest to what: stolen, chocolate, shot, lived, throws, him, frank, china,
# Nearest to buy: visit, party, not, visits, finish, many, loves, go,
# Nearest to future: old, boy, people, on, party, there, over, writes,
# Nearest to book: videotape, people, sell, man, go, boy, candy, chicken,
# Nearest to arrives: writes, reads, hit, leaves, won't, shot, loves, decides,
# Nearest to yesterday: visit, herself, is, candy, tells, sure, aside, loves,
# Nearest to can: should, to, will, really, teacher, finish, being, not,
# Average loss at step 82000: 0.155080
# Average loss at step 84000: 0.154724
# Average loss at step 86000: 0.153230
# Average loss at step 88000: 0.153722
# Average loss at step 90000: 0.156042
# Nearest to who: whom, him, homework, she, brother, mary, mother, eats,
# Nearest to in: give, john's, john, he, aside, car, of, ann,
# Nearest to house: party, movie, chicago, writes, there, box, loves, sure,
# Nearest to that: what, whom, to, blames, broccoli, eats, writes, can,
# Nearest to one: boy, UNK, owner, vegtables, for, ann, videotape, john,
# Nearest to to: should, is, can, frank's, aside, whom, has, that,
# Nearest to car: coat, there, movie, woman, boy, leaves, party, in,
# Nearest to the: china, chicago, some, down, told, here, many, blue,
# Nearest to mary: stolen, frank, who, leg, this, eats, fred, was,
# Nearest to a: down, old, some, was, not, mother, the, visit,
# Nearest to UNK: vegtables, one, for, homework, brother, boys, go, last,
# Nearest to is: loves, aside, visit, many, yesterday, to, likes, tells,
# Nearest to for: vegtables, owner, UNK, knows, one, homework, being, visit,
# Nearest to there: party, really, house, car, future, over, chicago, bill,
# Nearest to gives: searches, shot, box, leaves, writes, buys, doesn't, visited,
# Nearest to john's: name, in, frank's, which, all, knows, for, fish,
# Nearest to will: should, won't, blames, tells, prefers, gives, doesn't, visits,
# Nearest to john: in, one, ann, somebody, someones, bill, fish, sue,
# Nearest to should: can, will, likes, prefers, bought, to, gives, writes,
# Nearest to likes: prefers, should, decides, gives, wants, tells, writes, visits,
# Nearest to loves: blames, is, tells, finish, won't, wants, reads, visits,
# Nearest to visit: yesterday, is, finish, loves, knows, herself, buy, blames,
# Nearest to go: book, get, chocolate, know, buy, UNK, vegtables, hit,
# Nearest to what: stolen, chocolate, shot, lived, him, throws, frank, china,
# Nearest to buy: not, party, visits, many, visit, finish, go, loves,
# Nearest to future: people, old, boy, party, on, there, over, chicago,
# Nearest to book: videotape, sell, people, go, man, boy, candy, chicken,
# Nearest to arrives: writes, reads, hit, leaves, shot, won't, loves, decides,
# Nearest to yesterday: visit, herself, is, candy, tells, sure, aside, loves,
# Nearest to can: should, to, will, teacher, really, finish, being, not,
# Average loss at step 92000: 0.156400
# Average loss at step 94000: 0.152585
# Average loss at step 96000: 0.151934
# Average loss at step 98000: 0.152028
# Average loss at step 100000: 0.152895
# Nearest to who: whom, him, homework, brother, she, mary, mother, eats,
# Nearest to in: give, john, he, aside, john's, car, has, of,
# Nearest to house: party, movie, chicago, writes, there, box, loves, sure,
# Nearest to that: what, whom, blames, broccoli, to, eats, writes, him,
# Nearest to one: boy, UNK, owner, vegtables, for, ann, videotape, fish,
# Nearest to to: should, can, is, frank's, aside, whom, has, really,
# Nearest to car: coat, there, movie, party, boy, woman, leaves, really,
# Nearest to the: china, chicago, some, down, told, new, many, here,
# Nearest to mary: stolen, frank, this, leg, eats, who, fred, party,
# Nearest to a: down, old, some, was, not, mother, the, many,
# Nearest to UNK: vegtables, one, for, homework, brother, boys, go, last,
# Nearest to is: loves, aside, visit, many, yesterday, likes, tells, to,
# Nearest to for: vegtables, owner, UNK, knows, one, homework, being, visit,
# Nearest to there: party, car, really, house, future, over, chicago, bought,
# Nearest to gives: searches, shot, box, leaves, writes, buys, doesn't, visited,
# Nearest to john's: name, in, which, frank's, all, knows, for, fish,
# Nearest to will: should, won't, blames, prefers, tells, doesn't, gives, visits,
# Nearest to john: in, ann, somebody, one, someones, bill, fish, sue,
# Nearest to should: can, will, likes, prefers, bought, to, gives, writes,
# Nearest to likes: prefers, should, decides, gives, wants, visits, writes, tells,
# Nearest to loves: blames, is, tells, visits, won't, wants, reads, writes,
# Nearest to visit: yesterday, is, loves, finish, knows, herself, buy, blames,
# Nearest to go: book, chocolate, get, buy, know, UNK, vegtables, hit,
# Nearest to what: chocolate, stolen, lived, shot, him, throws, frank, china,
# Nearest to buy: party, many, visit, visits, not, loves, go, finish,
# Nearest to future: old, people, boy, party, on, leg, over, there,
# Nearest to book: videotape, sell, people, man, go, boy, candy, chicken,
# Nearest to arrives: writes, reads, hit, loves, shot, leaves, won't, decides,
# Nearest to yesterday: visit, herself, is, candy, sure, tells, aside, loves,
# Nearest to can: should, to, will, teacher, really, finish, being, not,

# %%
num_points = vocabulary_size-1

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
